# %%
import pandas as pd
import itertools as itt
import yaml
from collections import defaultdict
from pathlib import Path

# %%
HERE = Path("..").resolve()
HERE
# Out:
# PosixPath('/Users/cthoyt/dev/biocuration2023.github.io')

# %%
people = {}
name_to_person = {}
for fname in ["program_committee.yml", "organizing_committee.yml"]:
    path = HERE.joinpath("_data", fname)
    for record in yaml.safe_load(path.read_text()):
        people[record["orcid"]] = record
        name_to_person[record["personLabel"].split()[0].lower()] = record
name_to_person
# Out:
# {'frédérique': {'employerLabel_': 'University of Geneva',
#   'genderLabel': 'female',
#   'gscholar': 'wudILEcAAAAJ',
#   'linkedin': 'frederique-lisacek-6028275',
#   'nationalityLabel': 'France',
#   'orcid': '0000-0002-0948-4537',
#   'person': 'Q28609783',
#   'personDescription': 'French bioinformatician',
#   'personLabel': 'Frédérique Lisacek',
#   'topics': 'glycoproteomics, interactomics, protein-protein interaction, glycoprotein, Semantic Web',
#   'twitter': 'GlycomicsExpasy',
#   'note': 'Chair'},
#  'luana': {'employerLabel_': 'Tor Vergata University of Rome',
#   'genderLabel': 'female',
#   'gscholar': '_AvozfEAAAAJ',
#   'linkedin': 'luana-licata-22a62153',
#   'nationalityLabel': 'Italy',
#   'orcid': '0000-0001-5084-9000',
#   'person': 'Q30158411',
#   'personDescription': 'researcher',
#   'personLabel': 'Luana Licata',
#   'topics': 'host-pathogen interaction, biological database, biocuration, molecular interaction, protein-protein interaction, ontology',
#   'twitter': 'MINT_database',
#   'note': 'Co-Chair'},
#  'deepti': {'employerLabel_': 'European Bioinformatics Institute',
#   'genderLabel': 'female',
#   'github': 'deeptijk',
#   'gscholar': 'XFWqvB4AAAAJ',
#   'linkedin': 'deepti-jaiswal-kundu-16089113',
#   'max_start_date': '2018-05-01T00:00:00Z',
#   'nationalityLabel': 'India',
#   'orcid': '0000-0003-2989-5971',
#   'person': 'Q92814834',
#   'personDescription': 'researcher (ORCID 0000-0003-2989-5971)',
#   'personLabel': 'Deepti J Kundu',
#   'topics': 'small molecule, protein structure, proteomics, bioinformatics, carbohydrate',
#   'twitter': 'DeeptiJaiswal'},
#  'jennifer': {'employerLabel_': 'AstraZeneca',
#   'genderLabel': 'female',
#   'github': 'JenHarrow',
#   'gscholar': 'fmLAA9wAAAAJ',
#   'linkedin': 'jenniferharrow',
#   'nationalityLabel': 'United Kingdom',
#   'orcid': '0000-0003-0338-3070',
#   'person': 'Q28359351',
#   'personDescription': 'researcher',
#   'personLabel': 'Jennifer Harrow',
#   'topics': 'health data, phenomics, Genome Annotation, genome annotation, omics, biodiversity',
#   'twitter': 'JenHarrow'},
#  'livia': {'employerLabel_': 'Tor Vergata University of Rome',
#   'genderLabel': 'female',
#   'gscholar': 'teMivu0AAAAJ',
#   'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/Livia-Perfetto.jpg',
#   'linkedin': 'livia-perfetto-03238a48',
#   'max_start_date': '2017-11-01T00:00:00Z',
#   'nationalityLabel': 'Italy',
#   'orcid': '0000-0003-4392-8725',
#   'person': 'Q55117931',
#   'personDescription': 'researcher',
#   'personLabel': 'Livia Perfetto',
#   'topics': 'network analysis, biocuration, molecular interaction, signal transduction, systems biology, protein-protein interaction, ontology',
#   'twitter': 'PerfettoLivia'},
#  'marc': {'employerLabel_': "St. John's University",
#   'genderLabel': 'male',
#   'github': 'gillespm',
#   'gscholar': '2xOb5MMAAAAJ',
#   'linkedin': 'gillespm',
#   'max_start_date': '1999-01-01T00:00:00Z',
#   'nationalityLabel': 'United States of America',
#   'orcid': '0000-0002-5766-1702',
#   'person': 'Q55459118',
#   'personDescription': 'researcher',
#   'personLabel': 'Marc Gillespie',
#   'topics': 'protein science, proteomics, bioinformatics, toxicology, molecular biology',
#   'twitter': 'marcgillespie'},
#  'michael': {'employerLabel_': 'University of Zurich',
#   'genderLabel': 'male',
#   'github': 'mbaudis',
#   'gscholar': 'qKbjZK4AAAAJ',
#   'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/Michael-Baudis.jpg',
#   'linkedin': 'mbaudis',
#   'max_start_date': '2015-08-01T00:00:00Z',
#   'nationalityLabel': 'Switzerland',
#   'orcid': '0000-0002-9903-4248',
#   'person': 'Q30505717',
#   'personDescription': 'Professor of Bioinformatics',
#   'personLabel': 'Michael Baudis',
#   'topics': 'Global Alliance for Genomics and Health, genomics, ontology, hematology, oncogenomics, cancer',
#   'twitter': 'mbaudis'},
#  'peter': {'employerLabel_': 'Virginia Commonwealth University',
#   'genderLabel': 'male',
#   'gscholar': 'kBVT3a4AAAAJ',
#   'linkedin': 'peter-uetz-75935a16',
#   'max_start_date': '2011-01-01T00:00:00Z',
#   'nationalityLabel': 'Germany',
#   'orcid': '0000-0001-6194-4927',
#   'person': 'Q13220218',
#   'personDescription': 'researcher',
#   'personLabel': 'Peter Uetz',
#   'topics': 'Protein function prediction, protein-protein interaction, biodiversity',
#   'twitter': 'peteruetz'},
#  'sabrina': {'employerLabel_': 'University of Colorado',
#   'genderLabel': 'female',
#   'github': 'sabrinatoro',
#   'gscholar': '0EmO2vwAAAAJ',
#   'linkedin': 'sabrina-toro-8741732',
#   'orcid': '0000-0002-4142-7153',
#   'person': 'Q108416351',
#   'personDescription': 'researcher',
#   'personLabel': 'Sabrina Toro',
#   'topics': 'biocuration, animal model, ontology',
#   'twitter': 'curioussabrinat'},
#  'varsha': {'employerLabel_': 'Independent Data Curation Advisor',
#   'genderLabel': 'female',
#   'github': 'VarshaKhodiyar',
#   'gscholar': 'Vrg7RlAAAAAJ',
#   'linkedin': 'varshakhodiyar',
#   'max_start_date': '2022-05-01T00:00:00Z',
#   'nationalityLabel': 'United Kingdom',
#   'orcid': '0000-0002-2743-6918',
#   'person': 'Q53589893',
#   'personDescription': 'researcher',
#   'personLabel': 'Varsha Khodiyar',
#   'topics': 'data curation, data management, data governance',
#   'twitter': 'varsha_khodiyar'},
#  'federica': {'employerLabel_': 'University of Padua',
#   'genderLabel': 'female',
#   'github': 'federicaquaglia',
#   'gscholar': 'q5qtfVcAAAAJ',
#   'linkedin': 'federica-quaglia-b8497613b',
#   'max_start_date': '2021-01-03T00:00:00Z',
#   'nationalityLabel': 'Italy',
#   'orcid': '0000-0002-0341-4888',
#   'person': 'Q87054158',
#   'personDescription': 'biocurator, researcher',
#   'personLabel': 'Federica Quaglia',
#   'topics': 'biocuration, intrinsically unstructured proteins, protein-protein interaction, ontology',
#   'twitter': 'FedeQuaglia89',
#   'note': 'Chair'},
#  'charles': {'employerLabel_': 'Harvard Medical School',
#   'genderLabel': 'male',
#   'github': 'cthoyt',
#   'gscholar': 'PjrpzUIAAAAJ',
#   'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/Charles%20Tapley%20Hoyt%202019.jpg',
#   'linkedin': 'cthoyt',
#   'max_start_date': '2021-02-15T00:00:00Z',
#   'nationalityLabel': 'United States of America',
#   'orcid': '0000-0003-4423-4370',
#   'person': 'Q47475003',
#   'personDescription': 'American chemist',
#   'personLabel': 'Charles Tapley Hoyt',
#   'topics': 'knowledge graph, ontology, natural language processing',
#   'twitter': 'cthoyt',
#   'note': 'Co-Chair'},
#  'silvio': {'employerLabel_': 'University of Padua',
#   'genderLabel': 'male',
#   'nationalityLabel': 'Italy',
#   'orcid': '0000-0003-4525-7793',
#   'person': 'Q60220727',
#   'personDescription': None,
#   'personLabel': 'Silvio Tosatto',
#   'note': 'Co-Chair'},
#  'deepak': {'employerLabel_': 'SIB',
#   'genderLabel': 'male',
#   'github': 'deepakunni3',
#   'gscholar': '38ZnUjsAAAAJ',
#   'linkedin': 'deepakunni3',
#   'max_start_date': '2022-08-01T00:00:00Z',
#   'nationalityLabel': 'India',
#   'orcid': '0000-0002-3583-7340',
#   'person': 'Q59690671',
#   'personDescription': 'researcher ORCID ID = 0000-0002-3583-7340',
#   'personLabel': 'Deepak R. Unni',
#   'topics': 'data visualization, Genome browser, knowledge graph, semantic search, data modeling, genomics, ontology, Semantic Web',
#   'twitter': 'deepakunni3'},
#  'maria': {'orcid': '0000-0002-4937-6952',
#   'personLabel': 'Maria Cristina Aspromonte',
#   'person': 'Q90663571',
#   'nationalityLabel': 'Italy',
#   'employerLabel_': 'University of Padua'},
#  'monica': {'employerLabel_': 'University of Colorado',
#   'genderLabel': 'female',
#   'github': 'monicacecilia',
#   'gscholar': '0bGKBS0AAAAJ',
#   'linkedin': 'monimunozto',
#   'max_start_date': '2018-01-01T00:00:00Z',
#   'nationalityLabel': 'Colombia',
#   'orcid': '0000-0001-8430-6039',
#   'person': 'Q91376977',
#   'personDescription': 'researcher (ORCID 0000-0001-8430-6039)',
#   'personLabel': 'Monica Munoz-Torres',
#   'topics': 'knowledge representation and reasoning, biocuration, data science, comparative genomics, human disease, genomics',
#   'twitter': 'monimunozto'},
#  'paola': {'genderLabel': 'female',
#   'employerLabel_': 'Self-employed (SciBite consultant)',
#   'github': 'paolaroncaglia',
#   'gscholar': 'mruxdxAAAAAJ',
#   'linkedin': 'paolaroncaglia',
#   'nationalityLabel': 'Italy',
#   'orcid': '0000-0002-2825-0621',
#   'person': 'Q47139534',
#   'personDescription': 'researcher',
#   'personLabel': 'Paola Roncaglia',
#   'topics': 'transcriptomics, genome annotation, Genome Annotation, cell type, Gene Ontology, ontology',
#   'twitter': 'paola_roncaglia'},
#  'philippe': {'employerLabel_': 'SIB',
#   'genderLabel': 'male',
#   'gscholar': 'Bz8HmVoAAAAJ',
#   'linkedin': 'philippe-le-mercier-846b5713',
#   'max_start_date': '2004-01-01T00:00:00Z',
#   'nationalityLabel': 'Switzerland',
#   'orcid': '0000-0001-8528-090X',
#   'person': 'Q82415251',
#   'personDescription': 'researcher',
#   'personLabel': 'Philippe Le Mercier',
#   'topics': 'molecular virology, biocuration, bioinformatics, virology',
#   'twitter': 'ViralZone'},
#  'ruth': {'employerLabel_': 'University College London',
#   'genderLabel': 'female',
#   'github': 'RLovering',
#   'gscholar': '_os7irwAAAAJ',
#   'linkedin': 'ruthlovering',
#   'twitter': 'RuthCLovering',
#   'orcid': '0000-0002-9791-0064',
#   'person': 'Q53590460',
#   'personDescription': 'researcher',
#   'personLabel': 'Ruth Lovering',
#   'topics': ''},
#  'tiago': {'genderLabel': 'male',
#   'github': 'lubianat',
#   'gscholar': '_1bOZ5cAAAAJ',
#   'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/WikiCon%20Brasil%202022%20-%20Ferramentas%20de%20contribui%C3%A7%C3%A3o%20em%20massa%20no%20Wikidata%20e%20Commons%20-%20Tiago%20Lubiana%20%2802%29%20%28cropped%29.jpg',
#   'linkedin': 'tiago-lubiana-178a3784',
#   'employerLabel_': 'Universidade de São Paulo',
#   'nationalityLabel': 'Brazil',
#   'orcid': '0000-0003-2473-2313',
#   'person': 'Q90076935',
#   'personDescription': 'researcher',
#   'personLabel': 'Tiago Lubiana',
#   'topics': 'bioinformatics',
#   'twitter': 'lubianat'}}

# %%
# url = (
#     "https://docs.google.com/spreadsheets/d/e/2PACX-1vQDrUXGXhAyUUoeTpFV4eZ"
#     "JViSLAaFvY014X0UX_tHEoxgB6vgFVWRnfrbxjSa74w/pub?gid=1919588799&single=true&output=tsv"
# )
# print(f"Reading {url}")
# df = pd.read_csv(
#     url,
#     sep='\t',
#     skiprows=44, usecols=[0,1,2,3,4]
# )
df = pd.read_excel(
    "Biocuration 2023_submissions_2023-01-04_1672831641(1).xlsx", 
    skiprows=44, 
    usecols=[0,1,2,3,4],
)
df.columns = ['time', 'type', 'speaker', 'title', 'id']
df = df[df.time.notna()]
df
# Out:
#                                                  time  \
# 0                 Monday afternoon session: standards
# 1                                           4:30-4:50
# 2                                           4:50-5:10
# 3                                           5:10-5:30
# 4                                           5:30-5:40
# 5                                           5:40-5:50
# 6                                           5:50-6:00
# 8                     Tuesday morning session: FAIR 1
# 9                                         10:00-10:10
# 10                                        10:10-10:20
# 11                                        10:20-10:30
# 12                    Tuesday morning session: FAIR 2
# 13                                        11:00-11:20
# 14                                        11:20-11:40
# 15                                        11:40-12:00
# 16                                        12:00-12:10
# 17                                        12:10-12:20
# 18                                        12:20-12:30
# 19  Tuesday afternoon session (parallel 1): applic...
# 20                                          1:30-1:50
# 21                                          1:50-2:10
# 22                                          2:10-2:30
# 23  Tuesday afternoon session (parallel 1): applic...
# 24                                          2:45-2:55
# 25                                          2:55-3:05
# 26                                          3:05-3:15
# 27                                          3:15-3:25
# 28                                          3:25-3:35
# 29                                          3:35-3:45
# 30  Tuesday afternoon session (parallel 2): AI and...
# 31                                          1:30-1:50
# 32                                          1:50-2:10
# 33                                          2:10-2:20
# 34                                          2:20-2:30
# 35  Tuesday afternoon session (parallel 2): AI and...
# 36                                          2:45-2:55
# 37                                          2:55-3:05
# 38                                          3:05-3:15
# 39                                          3:15-3:25
# 40                                          3:25-3:35
# 41                                          3:35-3:45
# 43               Wednesday morning session: community
# 44                                        10:00-10:10
# 45                                        10:10-10:20
# 46                                        10:20-10:30
# 47             Wednesday afternoon session: community
# 48                                        13:00-13:20
# 49                                        13:20-13:40
# 50                                        13:40-14:00
# 51                                        14:00-14:10
# 52                                        14:10-14:20
# 53                                        14:20-14:30
# 55                                            Posters
#
#                         type  \
# 0                        NaN
# 1        long-20' (talk+Q&A)
# 2        long-20' (talk+Q&A)
# 3        long-20' (talk+Q&A)
# 4   lightning-10' (talk+Q&A)
# 5   lightning-10' (talk+Q&A)
# 6   lightning-10' (talk+Q&A)
# 8                        NaN
# 9   lightning-10' (talk+Q&A)
# 10  lightning-10' (talk+Q&A)
# 11  lightning-10' (talk+Q&A)
# 12                       NaN
# 13       long-20' (talk+Q&A)
# 14       long-20' (talk+Q&A)
# 15       long-20' (talk+Q&A)
# 16  lightning-10' (talk+Q&A)
# 17  lightning-10' (talk+Q&A)
# 18  lightning-10' (talk+Q&A)
# 19                       NaN
# 20       long-20' (talk+Q&A)
# 21       long-20' (talk+Q&A)
# 22       long-20' (talk+Q&A)
# 23                       NaN
# 24  lightning-10' (talk+Q&A)
# 25  lightning-10' (talk+Q&A)
# 26  lightning-10' (talk+Q&A)
# 27  lightning-10' (talk+Q&A)
# 28  lightning-10' (talk+Q&A)
# 29  lightning-10' (talk+Q&A)
# 30                       NaN
# 31       long-20' (talk+Q&A)
# 32       long-20' (talk+Q&A)
# 33  lightning-10' (talk+Q&A)
# 34  lightning-10' (talk+Q&A)
# 35                       NaN
# 36  lightning-10' (talk+Q&A)
# 37  lightning-10' (talk+Q&A)
# 38  lightning-10' (talk+Q&A)
# 39  lightning-10' (talk+Q&A)
# 40  lightning-10' (talk+Q&A)
# 41  lightning-10' (talk+Q&A)
# 43                       NaN
# 44  lightning-10' (talk+Q&A)
# 45  lightning-10' (talk+Q&A)
# 46  lightning-10' (talk+Q&A)
# 47                       NaN
# 48       long-20' (talk+Q&A)
# 49       long-20' (talk+Q&A)
# 50       long-20' (talk+Q&A)
# 51  lightning-10' (talk+Q&A)
# 52  lightning-10' (talk+Q&A)
# 53  lightning-10' (talk+Q&A)
# 55                       NaN
#
#                                               speaker  \
# 0                                                 NaN
# 1   Kalpana Panneerselvam, Pablo Porras, Noemi del...
# 2   Patrick Masson, Cristina Casals-Casas, Lionel ...
# 3   David Osumi-Sutherland, Robert Court, Huseyin ...
# 4   Qian Xiang, Edmund Su, Hardeep Nahal-Bose, Rob...
# 5   Marcela Tello-Ruiz, Nahla Bassil, Sebastian Be...
# 6   Yalan Bi, Nancy George, Irene Papatheodorou, A...
# 8                                                 NaN
# 9   Adel Bouhraoua, Federica Quaglia, Damiano Piov...
# 10  Frederic B. Bastian, Vincent Gardeux, Bart Dep...
# 11              Christopher Southan and Miguel Amaral
# 12                                                NaN
# 13  Christopher Hunter, Chris Armit, Mary Ann Tuli...
# 14  J. Harry Caufield, Justin Reese, Tudor Oprea, ...
# 15  Lynn M Schriml, J. Allen Baron, Dustin Olley, ...
# 16                          Wei Kheng Teh and Fuqi Xu
# 17  Peter Woollard, Stephane Pesant, Josephine Bur...
# 18   Jerven Bolleman, Alan Bridge and Nicole Redaschi
# 19                                                NaN
# 20  Silvio Tosatto, Maria Victoria Nugnes, Federic...
# 21  Brian Alcock, Amogelang Raphenya, Arman Edalat...
# 22  Elisabeth Coudert, Sebastien Gehant, Nicole Re...
# 23                                                NaN
# 24  Simona Panni, Kalpana Panneerselvam, Pablo Por...
# 25  Leigh C Carmody, Michael Gargano, Nicole A Vas...
# 26  Ulrike Wittig, Dorotea Dudaš, Maja Rey, Andrea...
# 27  Amogelang Raphenya, Michael Surette, Gerard Wr...
# 28  Ziying Yang, Rahel Paloots, Hangjia Zhao and M...
# 29  Sandra Orchard, Birgit Meldal, Helen Attrill, ...
# 30                                                NaN
# 31  Kimberly Van Auken, Valerio Arnaboldi, Daniela...
# 32  Rebecca Foulger, Jane Lomax, Rachael Huntley, ...
# 33  Carlos Vega, Marek Ostaszewski, Valentin Grouè...
# 34  Anne Niknejad, Vincent Gardeux, Fabrice David,...
# 35                                                NaN
# 36                                         Peter Uetz
# 37  Samir Gupta, Xihan Qin, Qinghua Wang, Julie Co...
# 38          Benjamin M. Gyori and Charles Tapley Hoyt
# 39  Emilie Pasche, Anaïs Mottaz, Julien Gobeill, P...
# 40  Rezarta Islamaj, Nicholas Miliaras, Olga Print...
# 41  Rossana Zaru, Vishal Joshi, Sandra Orchard and...
# 43                                                NaN
# 44  Marc Feuermann, Pascale Gaudet, Huaiyu Mi, Anu...
# 45  Catherine Hayes, Masaaki Shiota, Akihiro Fujit...
# 46                    Tiago Lubiana and Helder Nakaya
# 47                                                NaN
# 48          Charles Tapley Hoyt and Benjamin M. Gyori
# 49  Nancy George, Irene Papatheodorou, Anja Fullgr...
# 50                                   Arina Puzriakova
# 51  Marc Gillespie, Peter D'Eustachio, Robin Haw, ...
# 52  Irina Persikova, Jasmine Y. Young, Ezra Peisac...
# 53  Jennifer Harrow, Karyn Mégy, Amanda O'Neil, Ke...
# 55                                                NaN
#
#                                                 title      id
# 0                                                 NaN     NaN
# 1   Human-pathogen interaction networks: IMEx’s ap...  5380.0
# 2   Gene Ontology Causal Activity Models (GO-CAMs)...  6415.0
# 3                 The Knowledge Graph Development Kit  4113.0
# 4   ICGC-ARGO Data Submission Workflow - Integrati...  3601.0
# 5   Developing Standards for Biocuration & Interop...  8868.0
# 6    Multiplexed scRNA-seq Experiments in Biocuration  5715.0
# 8                                                 NaN     NaN
# 9   APICURON: standardizing attribution of biocura...   966.0
# 10  scFAIR: Standardization and stewardship of sin...  8261.0
# 11  Resolving code names to structures from the me...  8444.0
# 12                                                NaN     NaN
# 13  GigaDB: Utilising ontologies to curate data pu...  2885.0
# 14  KG-IDG: A FAIR Knowledge Graph for Illuminatin...   673.0
# 15  A 20 year perspective on FAIR and TRUST-worthy...   371.0
# 16  FAIR Wizard: Making the FAIRification process ...  9192.0
# 17  Providing Expanded Contextual Metadata for Bio...  4905.0
# 18        Making expert curated knowledge graphs FAIR  7142.0
# 19                                                NaN     NaN
# 20  Biocuration in DisProt, the manually curated d...  1006.0
# 21  The Comprehensive Antibiotic Resistance Databa...  7692.0
# 22  Annotation of biologically relevant ligands in...  2833.0
# 23                                                NaN     NaN
# 24  The landscape of microRNA interactions annotat...  7839.0
# 25  Medical Action Ontology (MAxO) development and...  1874.0
# 26  Improved Insights into the SABIO-RK Database v...  8451.0
# 27  The Human Microbiome Drug Metabolism (HMDM) Da...  6403.0
# 28  Phenopackets for curated repository data over ...  6778.0
# 29  Unifying Protein Complex Curation across the D...  6299.0
# 30                                                NaN     NaN
# 31  ACKnowledge: expanding community curation to i...  9967.0
# 32          Machine Learning for Scalable Biocuration  4380.0
# 33  BioKC: a collaborative platform for curation a...  6685.0
# 34  Building a reference dataset of single-cell RN...  9482.0
# 35                                                NaN     NaN
# 36  Curating species descriptions for the digital age  9553.0
# 37  eMIND: Enabling automatic collection of protei...  9773.0
# 38  Machine-assisted curation of molecular mechani...  9399.0
# 39  Assessing the Use of Supplementary Materials t...  9409.0
# 40  A Framework for Assisting MeSH Vocabulary Deve...  3753.0
# 41  Predicting protein metal binding sites with ar...   671.0
# 43                                                NaN     NaN
# 44  A complete draft human gene functionome from l...   885.0
# 45  Towards making sense of glycan-mediated protei...  7461.0
# 46   Wikidata as a tool for biocuration of cell types  8085.0
# 47                                                NaN     NaN
# 48  Promoting the longevity of curated scientific ...  6726.0
# 49  Single Cell Expression Atlas and FlyBase - the...   259.0
# 50  Leveraging crowdsourcing and curation prioriti...  5319.0
# 51  Community SARS-CoV-2 Curation Driven Emergent ...   796.0
# 52  wwPDB Biocuration: Supporting Advances in Scie...  4600.0
# 53  Accessing UK Biobank-derived data through the ...  7199.0
# 55                                                NaN     NaN

# %%
groups = defaultdict(list)
current_group_name = None

def fix_authors(s):
    return s.split(",")[0].strip().split(" and ")[0].strip()

def fix_type(s):
    if s == "long-20' (talk+Q&A)":
        return "long"
    if s == "lightning-10' (talk+Q&A)":
        return "lightning"
    raise ValueError(s)

    
def get_times(s):
    start_time, end_time = map(clean_time, map(str.strip, time.split("-")))
    return start_time, end_time
    
def clean_time(s):
    h, m = s.split(":")
    if int(h) <8:
        # print("old h", h, end=" ")
        h = str(int(h) + 12)
        # print("new h", h)
    return f"{h}.{m}"
    
    
columns =['time_start', 'time_end', 'type', 'speaker', 'title', 'id']
    
for time, talk_type, authors, title, idx in df.values:
    if not time[0].isdigit():
        current_group_name = time
        continue
    else:
        start_time, end_time = get_times(time)
        groups[current_group_name].append((
            start_time, end_time, fix_type(talk_type), fix_authors(authors), title, int(idx),
        ))

groups = {g: pd.DataFrame(l, columns=columns) for g, l in groups.items()}

# %%
info = [
    {
        "day": "Monday",
        "date": "April 24th",
        "sessions": {
            'Monday Salutation': dict(
                chair="charles",
                cochair="silvio",
                order=0,
                room="Sala Piero Tortolina Auditorium",
                start="14.30",
                end="14.45",
                title="Conference Salutation",

            ),
            'Monday Salutation ISB': dict(
                chair="charles",
                cochair="silvio",
                order=0.5,
                room="Sala Piero Tortolina Auditorium",
                start="14.45",
                end="15.00",
                title="ISB Greeting from Ruth Lovering (ISB EC Chair)",
            ),
            'Monday Keynote': dict(
                chair="charles",
                cochair="deepti",
                order=1,
                room="Sala Piero Tortolina Auditorium",
                title="Keynote 1 - Paula Leitman",
                start="15.00",
                end="16.00",
                day="Monday",
                date="April 24th",
            ),
            'Monday afternoon session: standards': dict(
                order=2,
                day="Monday",
                date="April 24th",
                start="16.30",
                end="18.00",
                title="Standards 1",
                chair="frédérique",
                cochair="deepti",
                room="Sala Piero Tortolina Auditorium",
            ),
        },
    },
    {
        "day": "Tuesday",
        "date": "April 25th",
        "sessions": {
            'Tuesday Keynote': dict(
                cochair="deepak",
                chair="paola",
                order=3,
                room="Sala Piero Tortolina Auditorium",
                title="Keynote 2 - Marco Roos",
                start="9.00",
                end="10.00",
                day="Tuesday",
                date=" April 25th",
            ),
            'Tuesday morning session: FAIR 1': dict(
                order=4,
                day="Tuesday",
                date=" April 25th",
                start="10.00",
                end="10.30",
                title="FAIR 1",
                chair="deepak",
                cochair="paola",
                room="Sala Piero Tortolina Auditorium",
            ), 
            'Tuesday morning session: FAIR 2': dict(
                order=5,
                day="Tuesday",
                date=" April 25th",
                start="11.00",
                end="12.30",
                title="FAIR 2",
                chair="deepak",
                cochair="paola",
                room="Sala Piero Tortolina Auditorium",
            ), 
            'Tuesday afternoon session (parallel 1): applications 1': dict(
                order=6,
                day="Tuesday",
                date="April 25th",
                start="13.30",
                end="14.30",
                title="Applications 1",
                chair="Philippe",
                cochair="Michael",
                room="Sala Piero Tortolina Auditorium",
            ), 
            'Tuesday afternoon session (parallel 2): AI and Text mining 1': dict(
                order=7,
                day="Tuesday",
                date="April 25th",
                start="13.30",
                end="14.30",
                title="AI and Text Mining 1",
                chair="Jennifer",
                cochair="Tiago",
                room="Spazio 35",
            ),
            'Tuesday afternoon session (parallel 1): applications 2': dict(
                order=8,
                day="Tuesday",
                date="April 25th",
                start="14.45",
                end="15.45",
                title="Applications 2",
                chair="Michael",
                cochair="Philippe",
                room="Sala Piero Tortolina Auditorium",
            ),
            'Tuesday afternoon session (parallel 2): AI and Text mining 2': dict(
                order=9,
                day="Tuesday",
                date="April 25th",
                start="14.45",
                end="15.45",
                title="AI and Text Mining 2",
                chair="Tiago",
                cochair="Jennifer",
                room="Spazio 35",
            ),
            'Tuesday Poster Session 1': dict(
                order=10,
                day="Tuesday",
                date="April 25th",
                start="16.00",
                end="17.00",
                title="Poster Session 1 (Even Numbers)",
                room="Agora",
            ),
            'Tuesday Poster Session 2': dict(
                order=11,
                day="Tuesday",
                date="April 25th",
                start="17.00",
                end="18.00",
                title="Poster Session 2 (Odd Numbers)",
                room="Agora",
            ),
        }
    },
    {
        "day": "Wednesday",
        "date": "April 26th",
        "sessions": {
            'Wednesday Keynote': dict(
                order=10,
                chair="luana",
                cochair="deepti",
                room="Sala Piero Tortolina Auditorium",
                title="Keynote 3 - Guy Cochrane",
                start="9.00",
                end="10.00",
                day="Wednesday",
                date="April 26th",
            ),
            'Wednesday morning session: community': dict(
                order=11,
                day="Wednesday",
                date="April 26th",
                start="10.00",
                end="10.30",
                title="Community 1",
                chair="Luana",
                cochair="frédérique",
                room="Sala Piero Tortolina Auditorium",
            ),
            "Wednesday Careers in Biocuration": dict(
                order=12,
                chair="deepti",
                day="Wednesday",
                date="April 26th",
                cochair="philippe",
                room="Sala Piero Tortolina Auditorium",
                title="Careers in Biocuration Panel/Workshop",
                start="11.00",
                end="12.00",
            ),
            'Wednesday afternoon session: community': dict(
                order=13,
                day="Wednesday",
                date="April 26th",
                start="13.00",
                end="14.30",
                title="Community 2",
                chair="frédérique",
                cochair="Luana",
                room="Sala Piero Tortolina Auditorium",
            ),
            "Wednesday Valediction": dict(
                order=14,
                chair="charles",
                cochair="silvio",
                start="14.30",
                end="15.30",
                title="Valediction and ISB Time",
                room="Sala Piero Tortolina Auditorium",
            ),
        }
    }
]

# %%
for day in info:
    rows = []
    for key, data in sorted(day['sessions'].items(), key=lambda e: e[1]["order"]):
        if (groups_df := groups.get(key)) is not None:
            data["talks"] = groups_df.to_dict(orient="records")
        chairs = [
            name_to_person[data.pop(chair_key).lower()].copy()            
            for chair_key in ["chair", "cochair"]
            if chair_key in data
        ]
        if chairs:
            data["chairs"] = chairs
        rows.append(data)
        
    day["sessions"] = rows
info
# Out:
# [{'day': 'Monday',
#   'date': 'April 24th',
#   'sessions': [{'order': 0,
#     'room': 'Sala Piero Tortolina Auditorium',
#     'start': '14.30',
#     'end': '14.45',
#     'title': 'Conference Salutation',
#     'chairs': [{'employerLabel_': 'Harvard Medical School',
#       'genderLabel': 'male',
#       'github': 'cthoyt',
#       'gscholar': 'PjrpzUIAAAAJ',
#       'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/Charles%20Tapley%20Hoyt%202019.jpg',
#       'linkedin': 'cthoyt',
#       'max_start_date': '2021-02-15T00:00:00Z',
#       'nationalityLabel': 'United States of America',
#       'orcid': '0000-0003-4423-4370',
#       'person': 'Q47475003',
#       'personDescription': 'American chemist',
#       'personLabel': 'Charles Tapley Hoyt',
#       'topics': 'knowledge graph, ontology, natural language processing',
#       'twitter': 'cthoyt',
#       'note': 'Co-Chair'},
#      {'employerLabel_': 'University of Padua',
#       'genderLabel': 'male',
#       'nationalityLabel': 'Italy',
#       'orcid': '0000-0003-4525-7793',
#       'person': 'Q60220727',
#       'personDescription': None,
#       'personLabel': 'Silvio Tosatto',
#       'note': 'Co-Chair'}]},
#    {'order': 0.5,
#     'room': 'Sala Piero Tortolina Auditorium',
#     'start': '14.45',
#     'end': '15.00',
#     'title': 'ISB Greeting from Ruth Lovering (ISB EC Chair)',
#     'chairs': [{'employerLabel_': 'Harvard Medical School',
#       'genderLabel': 'male',
#       'github': 'cthoyt',
#       'gscholar': 'PjrpzUIAAAAJ',
#       'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/Charles%20Tapley%20Hoyt%202019.jpg',
#       'linkedin': 'cthoyt',
#       'max_start_date': '2021-02-15T00:00:00Z',
#       'nationalityLabel': 'United States of America',
#       'orcid': '0000-0003-4423-4370',
#       'person': 'Q47475003',
#       'personDescription': 'American chemist',
#       'personLabel': 'Charles Tapley Hoyt',
#       'topics': 'knowledge graph, ontology, natural language processing',
#       'twitter': 'cthoyt',
#       'note': 'Co-Chair'},
#      {'employerLabel_': 'University of Padua',
#       'genderLabel': 'male',
#       'nationalityLabel': 'Italy',
#       'orcid': '0000-0003-4525-7793',
#       'person': 'Q60220727',
#       'personDescription': None,
#       'personLabel': 'Silvio Tosatto',
#       'note': 'Co-Chair'}]},
#    {'order': 1,
#     'room': 'Sala Piero Tortolina Auditorium',
#     'title': 'Keynote 1 - Paula Leitman',
#     'start': '15.00',
#     'end': '16.00',
#     'day': 'Monday',
#     'date': 'April 24th',
#     'chairs': [{'employerLabel_': 'Harvard Medical School',
#       'genderLabel': 'male',
#       'github': 'cthoyt',
#       'gscholar': 'PjrpzUIAAAAJ',
#       'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/Charles%20Tapley%20Hoyt%202019.jpg',
#       'linkedin': 'cthoyt',
#       'max_start_date': '2021-02-15T00:00:00Z',
#       'nationalityLabel': 'United States of America',
#       'orcid': '0000-0003-4423-4370',
#       'person': 'Q47475003',
#       'personDescription': 'American chemist',
#       'personLabel': 'Charles Tapley Hoyt',
#       'topics': 'knowledge graph, ontology, natural language processing',
#       'twitter': 'cthoyt',
#       'note': 'Co-Chair'},
#      {'employerLabel_': 'European Bioinformatics Institute',
#       'genderLabel': 'female',
#       'github': 'deeptijk',
#       'gscholar': 'XFWqvB4AAAAJ',
#       'linkedin': 'deepti-jaiswal-kundu-16089113',
#       'max_start_date': '2018-05-01T00:00:00Z',
#       'nationalityLabel': 'India',
#       'orcid': '0000-0003-2989-5971',
#       'person': 'Q92814834',
#       'personDescription': 'researcher (ORCID 0000-0003-2989-5971)',
#       'personLabel': 'Deepti J Kundu',
#       'topics': 'small molecule, protein structure, proteomics, bioinformatics, carbohydrate',
#       'twitter': 'DeeptiJaiswal'}]},
#    {'order': 2,
#     'day': 'Monday',
#     'date': 'April 24th',
#     'start': '16.30',
#     'end': '18.00',
#     'title': 'Standards 1',
#     'room': 'Sala Piero Tortolina Auditorium',
#     'talks': [{'time_start': '16.30',
#       'time_end': '16.50',
#       'type': 'long',
#       'speaker': 'Kalpana Panneerselvam',
#       'title': 'Human-pathogen interaction networks: IMEx’s approach on the contextual metadata of the experimental evidence.',
#       'id': 5380},
#      {'time_start': '16.50',
#       'time_end': '17.10',
#       'type': 'long',
#       'speaker': 'Patrick Masson',
#       'title': 'Gene Ontology Causal Activity Models (GO-CAMs) for human biology',
#       'id': 6415},
#      {'time_start': '17.10',
#       'time_end': '17.30',
#       'type': 'long',
#       'speaker': 'David Osumi-Sutherland',
#       'title': 'The Knowledge Graph Development Kit',
#       'id': 4113},
#      {'time_start': '17.30',
#       'time_end': '17.40',
#       'type': 'lightning',
#       'speaker': 'Qian Xiang',
#       'title': 'ICGC-ARGO Data Submission Workflow - Integration of data validation and submission to accelerate the data curation and improve the data quality',
#       'id': 3601},
#      {'time_start': '17.40',
#       'time_end': '17.50',
#       'type': 'lightning',
#       'speaker': 'Marcela Tello-Ruiz',
#       'title': 'Developing Standards for Biocuration & Interoperability of Genetic Variation Data in Agricultural Research',
#       'id': 8868},
#      {'time_start': '17.50',
#       'time_end': '18.00',
#       'type': 'lightning',
#       'speaker': 'Yalan Bi',
#       'title': 'Multiplexed scRNA-seq Experiments in Biocuration',
#       'id': 5715}],
#     'chairs': [{'employerLabel_': 'University of Geneva',
#       'genderLabel': 'female',
#       'gscholar': 'wudILEcAAAAJ',
#       'linkedin': 'frederique-lisacek-6028275',
#       'nationalityLabel': 'France',
#       'orcid': '0000-0002-0948-4537',
#       'person': 'Q28609783',
#       'personDescription': 'French bioinformatician',
#       'personLabel': 'Frédérique Lisacek',
#       'topics': 'glycoproteomics, interactomics, protein-protein interaction, glycoprotein, Semantic Web',
#       'twitter': 'GlycomicsExpasy',
#       'note': 'Chair'},
#      {'employerLabel_': 'European Bioinformatics Institute',
#       'genderLabel': 'female',
#       'github': 'deeptijk',
#       'gscholar': 'XFWqvB4AAAAJ',
#       'linkedin': 'deepti-jaiswal-kundu-16089113',
#       'max_start_date': '2018-05-01T00:00:00Z',
#       'nationalityLabel': 'India',
#       'orcid': '0000-0003-2989-5971',
#       'person': 'Q92814834',
#       'personDescription': 'researcher (ORCID 0000-0003-2989-5971)',
#       'personLabel': 'Deepti J Kundu',
#       'topics': 'small molecule, protein structure, proteomics, bioinformatics, carbohydrate',
#       'twitter': 'DeeptiJaiswal'}]}]},
#  {'day': 'Tuesday',
#   'date': 'April 25th',
#   'sessions': [{'order': 3,
#     'room': 'Sala Piero Tortolina Auditorium',
#     'title': 'Keynote 2 - Marco Roos',
#     'start': '9.00',
#     'end': '10.00',
#     'day': 'Tuesday',
#     'date': ' April 25th',
#     'chairs': [{'genderLabel': 'female',
#       'employerLabel_': 'Self-employed (SciBite consultant)',
#       'github': 'paolaroncaglia',
#       'gscholar': 'mruxdxAAAAAJ',
#       'linkedin': 'paolaroncaglia',
#       'nationalityLabel': 'Italy',
#       'orcid': '0000-0002-2825-0621',
#       'person': 'Q47139534',
#       'personDescription': 'researcher',
#       'personLabel': 'Paola Roncaglia',
#       'topics': 'transcriptomics, genome annotation, Genome Annotation, cell type, Gene Ontology, ontology',
#       'twitter': 'paola_roncaglia'},
#      {'employerLabel_': 'SIB',
#       'genderLabel': 'male',
#       'github': 'deepakunni3',
#       'gscholar': '38ZnUjsAAAAJ',
#       'linkedin': 'deepakunni3',
#       'max_start_date': '2022-08-01T00:00:00Z',
#       'nationalityLabel': 'India',
#       'orcid': '0000-0002-3583-7340',
#       'person': 'Q59690671',
#       'personDescription': 'researcher ORCID ID = 0000-0002-3583-7340',
#       'personLabel': 'Deepak R. Unni',
#       'topics': 'data visualization, Genome browser, knowledge graph, semantic search, data modeling, genomics, ontology, Semantic Web',
#       'twitter': 'deepakunni3'}]},
#    {'order': 4,
#     'day': 'Tuesday',
#     'date': ' April 25th',
#     'start': '10.00',
#     'end': '10.30',
#     'title': 'FAIR 1',
#     'room': 'Sala Piero Tortolina Auditorium',
#     'talks': [{'time_start': '10.00',
#       'time_end': '10.10',
#       'type': 'lightning',
#       'speaker': 'Adel Bouhraoua',
#       'title': 'APICURON: standardizing attribution of biocuration activity to promote engagement',
#       'id': 966},
#      {'time_start': '10.10',
#       'time_end': '10.20',
#       'type': 'lightning',
#       'speaker': 'Frederic B. Bastian',
#       'title': 'scFAIR: Standardization and stewardship of single-cell metadata',
#       'id': 8261},
#      {'time_start': '10.20',
#       'time_end': '10.30',
#       'type': 'lightning',
#       'speaker': 'Christopher Southan',
#       'title': 'Resolving code names to structures from the medicinal chemistry literature: not as FAIR as it should be',
#       'id': 8444}],
#     'chairs': [{'employerLabel_': 'SIB',
#       'genderLabel': 'male',
#       'github': 'deepakunni3',
#       'gscholar': '38ZnUjsAAAAJ',
#       'linkedin': 'deepakunni3',
#       'max_start_date': '2022-08-01T00:00:00Z',
#       'nationalityLabel': 'India',
#       'orcid': '0000-0002-3583-7340',
#       'person': 'Q59690671',
#       'personDescription': 'researcher ORCID ID = 0000-0002-3583-7340',
#       'personLabel': 'Deepak R. Unni',
#       'topics': 'data visualization, Genome browser, knowledge graph, semantic search, data modeling, genomics, ontology, Semantic Web',
#       'twitter': 'deepakunni3'},
#      {'genderLabel': 'female',
#       'employerLabel_': 'Self-employed (SciBite consultant)',
#       'github': 'paolaroncaglia',
#       'gscholar': 'mruxdxAAAAAJ',
#       'linkedin': 'paolaroncaglia',
#       'nationalityLabel': 'Italy',
#       'orcid': '0000-0002-2825-0621',
#       'person': 'Q47139534',
#       'personDescription': 'researcher',
#       'personLabel': 'Paola Roncaglia',
#       'topics': 'transcriptomics, genome annotation, Genome Annotation, cell type, Gene Ontology, ontology',
#       'twitter': 'paola_roncaglia'}]},
#    {'order': 5,
#     'day': 'Tuesday',
#     'date': ' April 25th',
#     'start': '11.00',
#     'end': '12.30',
#     'title': 'FAIR 2',
#     'room': 'Sala Piero Tortolina Auditorium',
#     'talks': [{'time_start': '11.00',
#       'time_end': '11.20',
#       'type': 'long',
#       'speaker': 'Christopher Hunter',
#       'title': 'GigaDB: Utilising ontologies to curate data publications',
#       'id': 2885},
#      {'time_start': '11.20',
#       'time_end': '11.40',
#       'type': 'long',
#       'speaker': 'J. Harry Caufield',
#       'title': 'KG-IDG: A FAIR Knowledge Graph for Illuminating the Druggable Genome',
#       'id': 673},
#      {'time_start': '11.40',
#       'time_end': '12.00',
#       'type': 'long',
#       'speaker': 'Lynn M Schriml',
#       'title': 'A 20 year perspective on FAIR and TRUST-worthy Human Disease Knowledge Representation.',
#       'id': 371},
#      {'time_start': '12.00',
#       'time_end': '12.10',
#       'type': 'lightning',
#       'speaker': 'Wei Kheng Teh',
#       'title': 'FAIR Wizard: Making the FAIRification process accessible',
#       'id': 9192},
#      {'time_start': '12.10',
#       'time_end': '12.20',
#       'type': 'lightning',
#       'speaker': 'Peter Woollard',
#       'title': 'Providing Expanded Contextual Metadata for Biological Samples using Both Geographic and Taxonomic Factors',
#       'id': 4905},
#      {'time_start': '12.20',
#       'time_end': '12.30',
#       'type': 'lightning',
#       'speaker': 'Jerven Bolleman',
#       'title': 'Making expert curated knowledge graphs FAIR',
#       'id': 7142}],
#     'chairs': [{'employerLabel_': 'SIB',
#       'genderLabel': 'male',
#       'github': 'deepakunni3',
#       'gscholar': '38ZnUjsAAAAJ',
#       'linkedin': 'deepakunni3',
#       'max_start_date': '2022-08-01T00:00:00Z',
#       'nationalityLabel': 'India',
#       'orcid': '0000-0002-3583-7340',
#       'person': 'Q59690671',
#       'personDescription': 'researcher ORCID ID = 0000-0002-3583-7340',
#       'personLabel': 'Deepak R. Unni',
#       'topics': 'data visualization, Genome browser, knowledge graph, semantic search, data modeling, genomics, ontology, Semantic Web',
#       'twitter': 'deepakunni3'},
#      {'genderLabel': 'female',
#       'employerLabel_': 'Self-employed (SciBite consultant)',
#       'github': 'paolaroncaglia',
#       'gscholar': 'mruxdxAAAAAJ',
#       'linkedin': 'paolaroncaglia',
#       'nationalityLabel': 'Italy',
#       'orcid': '0000-0002-2825-0621',
#       'person': 'Q47139534',
#       'personDescription': 'researcher',
#       'personLabel': 'Paola Roncaglia',
#       'topics': 'transcriptomics, genome annotation, Genome Annotation, cell type, Gene Ontology, ontology',
#       'twitter': 'paola_roncaglia'}]},
#    {'order': 6,
#     'day': 'Tuesday',
#     'date': 'April 25th',
#     'start': '13.30',
#     'end': '14.30',
#     'title': 'Applications 1',
#     'room': 'Sala Piero Tortolina Auditorium',
#     'talks': [{'time_start': '13.30',
#       'time_end': '13.50',
#       'type': 'long',
#       'speaker': 'Silvio Tosatto',
#       'title': 'Biocuration in DisProt, the manually curated database for intrinsically disordered proteins',
#       'id': 1006},
#      {'time_start': '13.50',
#       'time_end': '14.10',
#       'type': 'long',
#       'speaker': 'Brian Alcock',
#       'title': 'The Comprehensive Antibiotic Resistance Database - Curating the Global Resistome',
#       'id': 7692},
#      {'time_start': '14.10',
#       'time_end': '14.30',
#       'type': 'long',
#       'speaker': 'Elisabeth Coudert',
#       'title': 'Annotation of biologically relevant ligands in UniProtKB using ChEBI',
#       'id': 2833}],
#     'chairs': [{'employerLabel_': 'SIB',
#       'genderLabel': 'male',
#       'gscholar': 'Bz8HmVoAAAAJ',
#       'linkedin': 'philippe-le-mercier-846b5713',
#       'max_start_date': '2004-01-01T00:00:00Z',
#       'nationalityLabel': 'Switzerland',
#       'orcid': '0000-0001-8528-090X',
#       'person': 'Q82415251',
#       'personDescription': 'researcher',
#       'personLabel': 'Philippe Le Mercier',
#       'topics': 'molecular virology, biocuration, bioinformatics, virology',
#       'twitter': 'ViralZone'},
#      {'employerLabel_': 'University of Zurich',
#       'genderLabel': 'male',
#       'github': 'mbaudis',
#       'gscholar': 'qKbjZK4AAAAJ',
#       'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/Michael-Baudis.jpg',
#       'linkedin': 'mbaudis',
#       'max_start_date': '2015-08-01T00:00:00Z',
#       'nationalityLabel': 'Switzerland',
#       'orcid': '0000-0002-9903-4248',
#       'person': 'Q30505717',
#       'personDescription': 'Professor of Bioinformatics',
#       'personLabel': 'Michael Baudis',
#       'topics': 'Global Alliance for Genomics and Health, genomics, ontology, hematology, oncogenomics, cancer',
#       'twitter': 'mbaudis'}]},
#    {'order': 7,
#     'day': 'Tuesday',
#     'date': 'April 25th',
#     'start': '13.30',
#     'end': '14.30',
#     'title': 'AI and Text Mining 1',
#     'room': 'Spazio 35',
#     'talks': [{'time_start': '13.30',
#       'time_end': '13.50',
#       'type': 'long',
#       'speaker': 'Kimberly Van Auken',
#       'title': 'ACKnowledge: expanding community curation to include fact extraction using artificial intelligence',
#       'id': 9967},
#      {'time_start': '13.50',
#       'time_end': '14.10',
#       'type': 'long',
#       'speaker': 'Rebecca Foulger',
#       'title': 'Machine Learning for Scalable Biocuration',
#       'id': 4380},
#      {'time_start': '14.10',
#       'time_end': '14.20',
#       'type': 'lightning',
#       'speaker': 'Carlos Vega',
#       'title': 'BioKC: a collaborative platform for curation and annotation of molecular interactions',
#       'id': 6685},
#      {'time_start': '14.20',
#       'time_end': '14.30',
#       'type': 'lightning',
#       'speaker': 'Anne Niknejad',
#       'title': 'Building a reference dataset of single-cell RNA-Seq data for training Machine-Learning algorithms',
#       'id': 9482}],
#     'chairs': [{'employerLabel_': 'AstraZeneca',
#       'genderLabel': 'female',
#       'github': 'JenHarrow',
#       'gscholar': 'fmLAA9wAAAAJ',
#       'linkedin': 'jenniferharrow',
#       'nationalityLabel': 'United Kingdom',
#       'orcid': '0000-0003-0338-3070',
#       'person': 'Q28359351',
#       'personDescription': 'researcher',
#       'personLabel': 'Jennifer Harrow',
#       'topics': 'health data, phenomics, Genome Annotation, genome annotation, omics, biodiversity',
#       'twitter': 'JenHarrow'},
#      {'genderLabel': 'male',
#       'github': 'lubianat',
#       'gscholar': '_1bOZ5cAAAAJ',
#       'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/WikiCon%20Brasil%202022%20-%20Ferramentas%20de%20contribui%C3%A7%C3%A3o%20em%20massa%20no%20Wikidata%20e%20Commons%20-%20Tiago%20Lubiana%20%2802%29%20%28cropped%29.jpg',
#       'linkedin': 'tiago-lubiana-178a3784',
#       'employerLabel_': 'Universidade de São Paulo',
#       'nationalityLabel': 'Brazil',
#       'orcid': '0000-0003-2473-2313',
#       'person': 'Q90076935',
#       'personDescription': 'researcher',
#       'personLabel': 'Tiago Lubiana',
#       'topics': 'bioinformatics',
#       'twitter': 'lubianat'}]},
#    {'order': 8,
#     'day': 'Tuesday',
#     'date': 'April 25th',
#     'start': '14.45',
#     'end': '15.45',
#     'title': 'Applications 2',
#     'room': 'Sala Piero Tortolina Auditorium',
#     'talks': [{'time_start': '14.45',
#       'time_end': '14.55',
#       'type': 'lightning',
#       'speaker': 'Simona Panni',
#       'title': 'The landscape of microRNA interactions annotation in IMEx: analysis of three rare disorders as case study',
#       'id': 7839},
#      {'time_start': '14.55',
#       'time_end': '15.05',
#       'type': 'lightning',
#       'speaker': 'Leigh C Carmody',
#       'title': 'Medical Action Ontology (MAxO) development and tool implementation for the annotation of Rare Disease (RD)',
#       'id': 1874},
#      {'time_start': '15.05',
#       'time_end': '15.15',
#       'type': 'lightning',
#       'speaker': 'Ulrike Wittig',
#       'title': 'Improved Insights into the SABIO-RK Database via Visualization',
#       'id': 8451},
#      {'time_start': '15.15',
#       'time_end': '15.25',
#       'type': 'lightning',
#       'speaker': 'Amogelang Raphenya',
#       'title': 'The Human Microbiome Drug Metabolism (HMDM) Database',
#       'id': 6403},
#      {'time_start': '15.25',
#       'time_end': '15.35',
#       'type': 'lightning',
#       'speaker': 'Ziying Yang',
#       'title': 'Phenopackets for curated repository data over Beacon v2 Progenetix database',
#       'id': 6778},
#      {'time_start': '15.35',
#       'time_end': '15.45',
#       'type': 'lightning',
#       'speaker': 'Sandra Orchard',
#       'title': 'Unifying Protein Complex Curation across the Diversity of Species',
#       'id': 6299}],
#     'chairs': [{'employerLabel_': 'University of Zurich',
#       'genderLabel': 'male',
#       'github': 'mbaudis',
#       'gscholar': 'qKbjZK4AAAAJ',
#       'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/Michael-Baudis.jpg',
#       'linkedin': 'mbaudis',
#       'max_start_date': '2015-08-01T00:00:00Z',
#       'nationalityLabel': 'Switzerland',
#       'orcid': '0000-0002-9903-4248',
#       'person': 'Q30505717',
#       'personDescription': 'Professor of Bioinformatics',
#       'personLabel': 'Michael Baudis',
#       'topics': 'Global Alliance for Genomics and Health, genomics, ontology, hematology, oncogenomics, cancer',
#       'twitter': 'mbaudis'},
#      {'employerLabel_': 'SIB',
#       'genderLabel': 'male',
#       'gscholar': 'Bz8HmVoAAAAJ',
#       'linkedin': 'philippe-le-mercier-846b5713',
#       'max_start_date': '2004-01-01T00:00:00Z',
#       'nationalityLabel': 'Switzerland',
#       'orcid': '0000-0001-8528-090X',
#       'person': 'Q82415251',
#       'personDescription': 'researcher',
#       'personLabel': 'Philippe Le Mercier',
#       'topics': 'molecular virology, biocuration, bioinformatics, virology',
#       'twitter': 'ViralZone'}]},
#    {'order': 9,
#     'day': 'Tuesday',
#     'date': 'April 25th',
#     'start': '14.45',
#     'end': '15.45',
#     'title': 'AI and Text Mining 2',
#     'room': 'Spazio 35',
#     'talks': [{'time_start': '14.45',
#       'time_end': '14.55',
#       'type': 'lightning',
#       'speaker': 'Peter Uetz',
#       'title': 'Curating species descriptions for the digital age',
#       'id': 9553},
#      {'time_start': '14.55',
#       'time_end': '15.05',
#       'type': 'lightning',
#       'speaker': 'Samir Gupta',
#       'title': 'eMIND: Enabling automatic collection of protein variation impacts in Alzheimer’s disease from the literature',
#       'id': 9773},
#      {'time_start': '15.05',
#       'time_end': '15.15',
#       'type': 'lightning',
#       'speaker': 'Benjamin M. Gyori',
#       'title': 'Machine-assisted curation of molecular mechanisms using automated knowledge extraction and assembly',
#       'id': 9399},
#      {'time_start': '15.15',
#       'time_end': '15.25',
#       'type': 'lightning',
#       'speaker': 'Emilie Pasche',
#       'title': 'Assessing the Use of Supplementary Materials to Improve Genomic Variant Discovery',
#       'id': 9409},
#      {'time_start': '15.25',
#       'time_end': '15.35',
#       'type': 'lightning',
#       'speaker': 'Rezarta Islamaj',
#       'title': 'A Framework for Assisting MeSH Vocabulary Development at the National Library of Medicine: Reliably Identifying Literature Containing New Chemical Substances',
#       'id': 3753},
#      {'time_start': '15.35',
#       'time_end': '15.45',
#       'type': 'lightning',
#       'speaker': 'Rossana Zaru',
#       'title': 'Predicting protein metal binding sites with artificial intelligence and machine learning in UniProt',
#       'id': 671}],
#     'chairs': [{'genderLabel': 'male',
#       'github': 'lubianat',
#       'gscholar': '_1bOZ5cAAAAJ',
#       'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/WikiCon%20Brasil%202022%20-%20Ferramentas%20de%20contribui%C3%A7%C3%A3o%20em%20massa%20no%20Wikidata%20e%20Commons%20-%20Tiago%20Lubiana%20%2802%29%20%28cropped%29.jpg',
#       'linkedin': 'tiago-lubiana-178a3784',
#       'employerLabel_': 'Universidade de São Paulo',
#       'nationalityLabel': 'Brazil',
#       'orcid': '0000-0003-2473-2313',
#       'person': 'Q90076935',
#       'personDescription': 'researcher',
#       'personLabel': 'Tiago Lubiana',
#       'topics': 'bioinformatics',
#       'twitter': 'lubianat'},
#      {'employerLabel_': 'AstraZeneca',
#       'genderLabel': 'female',
#       'github': 'JenHarrow',
#       'gscholar': 'fmLAA9wAAAAJ',
#       'linkedin': 'jenniferharrow',
#       'nationalityLabel': 'United Kingdom',
#       'orcid': '0000-0003-0338-3070',
#       'person': 'Q28359351',
#       'personDescription': 'researcher',
#       'personLabel': 'Jennifer Harrow',
#       'topics': 'health data, phenomics, Genome Annotation, genome annotation, omics, biodiversity',
#       'twitter': 'JenHarrow'}]},
#    {'order': 10,
#     'day': 'Tuesday',
#     'date': 'April 25th',
#     'start': '16.00',
#     'end': '17.00',
#     'title': 'Poster Session 1 (Even Numbers)',
#     'room': 'Agora'},
#    {'order': 11,
#     'day': 'Tuesday',
#     'date': 'April 25th',
#     'start': '17.00',
#     'end': '18.00',
#     'title': 'Poster Session 2 (Odd Numbers)',
#     'room': 'Agora'}]},
#  {'day': 'Wednesday',
#   'date': 'April 26th',
#   'sessions': [{'order': 10,
#     'room': 'Sala Piero Tortolina Auditorium',
#     'title': 'Keynote 3 - Guy Cochrane',
#     'start': '9.00',
#     'end': '10.00',
#     'day': 'Wednesday',
#     'date': 'April 26th',
#     'chairs': [{'employerLabel_': 'Tor Vergata University of Rome',
#       'genderLabel': 'female',
#       'gscholar': '_AvozfEAAAAJ',
#       'linkedin': 'luana-licata-22a62153',
#       'nationalityLabel': 'Italy',
#       'orcid': '0000-0001-5084-9000',
#       'person': 'Q30158411',
#       'personDescription': 'researcher',
#       'personLabel': 'Luana Licata',
#       'topics': 'host-pathogen interaction, biological database, biocuration, molecular interaction, protein-protein interaction, ontology',
#       'twitter': 'MINT_database',
#       'note': 'Co-Chair'},
#      {'employerLabel_': 'European Bioinformatics Institute',
#       'genderLabel': 'female',
#       'github': 'deeptijk',
#       'gscholar': 'XFWqvB4AAAAJ',
#       'linkedin': 'deepti-jaiswal-kundu-16089113',
#       'max_start_date': '2018-05-01T00:00:00Z',
#       'nationalityLabel': 'India',
#       'orcid': '0000-0003-2989-5971',
#       'person': 'Q92814834',
#       'personDescription': 'researcher (ORCID 0000-0003-2989-5971)',
#       'personLabel': 'Deepti J Kundu',
#       'topics': 'small molecule, protein structure, proteomics, bioinformatics, carbohydrate',
#       'twitter': 'DeeptiJaiswal'}]},
#    {'order': 11,
#     'day': 'Wednesday',
#     'date': 'April 26th',
#     'start': '10.00',
#     'end': '10.30',
#     'title': 'Community 1',
#     'room': 'Sala Piero Tortolina Auditorium',
#     'talks': [{'time_start': '10.00',
#       'time_end': '10.10',
#       'type': 'lightning',
#       'speaker': 'Marc Feuermann',
#       'title': 'A complete draft human gene functionome from large-scale evolutionary modeling and experimental Gene Ontology annotations',
#       'id': 885},
#      {'time_start': '10.10',
#       'time_end': '10.20',
#       'type': 'lightning',
#       'speaker': 'Catherine Hayes',
#       'title': 'Towards making sense of glycan-mediated protein-protein interactions',
#       'id': 7461},
#      {'time_start': '10.20',
#       'time_end': '10.30',
#       'type': 'lightning',
#       'speaker': 'Tiago Lubiana',
#       'title': 'Wikidata as a tool for biocuration of cell types',
#       'id': 8085}],
#     'chairs': [{'employerLabel_': 'Tor Vergata University of Rome',
#       'genderLabel': 'female',
#       'gscholar': '_AvozfEAAAAJ',
#       'linkedin': 'luana-licata-22a62153',
#       'nationalityLabel': 'Italy',
#       'orcid': '0000-0001-5084-9000',
#       'person': 'Q30158411',
#       'personDescription': 'researcher',
#       'personLabel': 'Luana Licata',
#       'topics': 'host-pathogen interaction, biological database, biocuration, molecular interaction, protein-protein interaction, ontology',
#       'twitter': 'MINT_database',
#       'note': 'Co-Chair'},
#      {'employerLabel_': 'University of Geneva',
#       'genderLabel': 'female',
#       'gscholar': 'wudILEcAAAAJ',
#       'linkedin': 'frederique-lisacek-6028275',
#       'nationalityLabel': 'France',
#       'orcid': '0000-0002-0948-4537',
#       'person': 'Q28609783',
#       'personDescription': 'French bioinformatician',
#       'personLabel': 'Frédérique Lisacek',
#       'topics': 'glycoproteomics, interactomics, protein-protein interaction, glycoprotein, Semantic Web',
#       'twitter': 'GlycomicsExpasy',
#       'note': 'Chair'}]},
#    {'order': 12,
#     'day': 'Wednesday',
#     'date': 'April 26th',
#     'room': 'Sala Piero Tortolina Auditorium',
#     'title': 'Careers in Biocuration Panel/Workshop',
#     'start': '11.00',
#     'end': '12.00',
#     'chairs': [{'employerLabel_': 'European Bioinformatics Institute',
#       'genderLabel': 'female',
#       'github': 'deeptijk',
#       'gscholar': 'XFWqvB4AAAAJ',
#       'linkedin': 'deepti-jaiswal-kundu-16089113',
#       'max_start_date': '2018-05-01T00:00:00Z',
#       'nationalityLabel': 'India',
#       'orcid': '0000-0003-2989-5971',
#       'person': 'Q92814834',
#       'personDescription': 'researcher (ORCID 0000-0003-2989-5971)',
#       'personLabel': 'Deepti J Kundu',
#       'topics': 'small molecule, protein structure, proteomics, bioinformatics, carbohydrate',
#       'twitter': 'DeeptiJaiswal'},
#      {'employerLabel_': 'SIB',
#       'genderLabel': 'male',
#       'gscholar': 'Bz8HmVoAAAAJ',
#       'linkedin': 'philippe-le-mercier-846b5713',
#       'max_start_date': '2004-01-01T00:00:00Z',
#       'nationalityLabel': 'Switzerland',
#       'orcid': '0000-0001-8528-090X',
#       'person': 'Q82415251',
#       'personDescription': 'researcher',
#       'personLabel': 'Philippe Le Mercier',
#       'topics': 'molecular virology, biocuration, bioinformatics, virology',
#       'twitter': 'ViralZone'}]},
#    {'order': 13,
#     'day': 'Wednesday',
#     'date': 'April 26th',
#     'start': '13.00',
#     'end': '14.30',
#     'title': 'Community 2',
#     'room': 'Sala Piero Tortolina Auditorium',
#     'talks': [{'time_start': '13.00',
#       'time_end': '13.20',
#       'type': 'long',
#       'speaker': 'Charles Tapley Hoyt',
#       'title': 'Promoting the longevity of curated scientific resources through open code, open data, and public infrastructure',
#       'id': 6726},
#      {'time_start': '13.20',
#       'time_end': '13.40',
#       'type': 'long',
#       'speaker': 'Nancy George',
#       'title': 'Single Cell Expression Atlas and FlyBase - the Fly Cell Atlas Anatomograms – where data meets art',
#       'id': 259},
#      {'time_start': '13.40',
#       'time_end': '14.00',
#       'type': 'long',
#       'speaker': 'Arina Puzriakova',
#       'title': 'Leveraging crowdsourcing and curation prioritisation for maintenance of clinical gene panels',
#       'id': 5319},
#      {'time_start': '14.00',
#       'time_end': '14.10',
#       'type': 'lightning',
#       'speaker': 'Marc Gillespie',
#       'title': 'Community SARS-CoV-2 Curation Driven Emergent Experiences - Increased Curation Efficiency and Learned Lessons for the Future',
#       'id': 796},
#      {'time_start': '14.10',
#       'time_end': '14.20',
#       'type': 'lightning',
#       'speaker': 'Irina Persikova',
#       'title': 'wwPDB Biocuration: Supporting Advances in Science and Technology',
#       'id': 4600},
#      {'time_start': '14.20',
#       'time_end': '14.30',
#       'type': 'lightning',
#       'speaker': 'Jennifer Harrow',
#       'title': 'Accessing UK Biobank-derived data through the AZ PheWAS portal, with reassigned phenotypic ICD10 codes.',
#       'id': 7199}],
#     'chairs': [{'employerLabel_': 'University of Geneva',
#       'genderLabel': 'female',
#       'gscholar': 'wudILEcAAAAJ',
#       'linkedin': 'frederique-lisacek-6028275',
#       'nationalityLabel': 'France',
#       'orcid': '0000-0002-0948-4537',
#       'person': 'Q28609783',
#       'personDescription': 'French bioinformatician',
#       'personLabel': 'Frédérique Lisacek',
#       'topics': 'glycoproteomics, interactomics, protein-protein interaction, glycoprotein, Semantic Web',
#       'twitter': 'GlycomicsExpasy',
#       'note': 'Chair'},
#      {'employerLabel_': 'Tor Vergata University of Rome',
#       'genderLabel': 'female',
#       'gscholar': '_AvozfEAAAAJ',
#       'linkedin': 'luana-licata-22a62153',
#       'nationalityLabel': 'Italy',
#       'orcid': '0000-0001-5084-9000',
#       'person': 'Q30158411',
#       'personDescription': 'researcher',
#       'personLabel': 'Luana Licata',
#       'topics': 'host-pathogen interaction, biological database, biocuration, molecular interaction, protein-protein interaction, ontology',
#       'twitter': 'MINT_database',
#       'note': 'Co-Chair'}]},
#    {'order': 14,
#     'start': '14.30',
#     'end': '15.30',
#     'title': 'Valediction and ISB Time',
#     'room': 'Sala Piero Tortolina Auditorium',
#     'chairs': [{'employerLabel_': 'Harvard Medical School',
#       'genderLabel': 'male',
#       'github': 'cthoyt',
#       'gscholar': 'PjrpzUIAAAAJ',
#       'image': 'http://commons.wikimedia.org/wiki/Special:FilePath/Charles%20Tapley%20Hoyt%202019.jpg',
#       'linkedin': 'cthoyt',
#       'max_start_date': '2021-02-15T00:00:00Z',
#       'nationalityLabel': 'United States of America',
#       'orcid': '0000-0003-4423-4370',
#       'person': 'Q47475003',
#       'personDescription': 'American chemist',
#       'personLabel': 'Charles Tapley Hoyt',
#       'topics': 'knowledge graph, ontology, natural language processing',
#       'twitter': 'cthoyt',
#       'note': 'Co-Chair'},
#      {'employerLabel_': 'University of Padua',
#       'genderLabel': 'male',
#       'nationalityLabel': 'Italy',
#       'orcid': '0000-0003-4525-7793',
#       'person': 'Q60220727',
#       'personDescription': None,
#       'personLabel': 'Silvio Tosatto',
#       'note': 'Co-Chair'}]}]}]

# %%
with open('/Users/cthoyt/dev/biocuration2023.github.io/_data/sessions.yml', 'w') as file:
    yaml.safe_dump(info, file, allow_unicode=True, sort_keys=True)
