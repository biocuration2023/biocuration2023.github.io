# %%
import pandas as pd
import itertools as itt
import yaml
from collections import defaultdict

# %%
url = (
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vQDrUXGXhAyUUoeTpFV4eZ"
    "JViSLAaFvY014X0UX_tHEoxgB6vgFVWRnfrbxjSa74w/pub?gid=1919588799&single=true&output=tsv"
)
df = pd.read_csv(
    url,
    sep='\t',
    skiprows=44, usecols=[0,1,2,3,4]
)
df.columns = ['time', 'type', 'speaker', 'title', 'id']
df = df[df.time.notna()]
df
# Out:
#                                                  time  \
# 0                 Monday afternoon session: standards
# 1                                           4:30-4:50
# 2                                           4:50-5:10
# 3                                           5:10-5:30
# 4                                           5:30-5:40
# 5                                           5:40-5:50
# 6                                           5:50-6:00
# 8                       Tuesday morning session: FAIR
# 9                                         10:00-10:10
# 10                                        10:10-10:20
# 11                                        10:20-10:30
# 12                                        11:00-11:20
# 13                                        11:20-11:40
# 14                                        11:40-12:00
# 15                                        12:00-12:10
# 16                                        12:10-12:20
# 17                                        12:20-12:30
# 19  Tuesday afternoon session (parallel 1): applic...
# 20                                          1:30-1:50
# 21                                          1:50-2:10
# 22                                          2:10-2:30
# 23                                          2:45-2:55
# 24                                          2:55-3:05
# 25                                          3:05-3:15
# 26                                          3:15-3:25
# 27                                          3:25-3:35
# 28                                          3:35-3:45
# 30  Tuesday afternoon session (parallel 2): AI and...
# 31                                          1:30-1:50
# 32                                          1:50-2:10
# 33                                          2:10-2:20
# 34                                          2:20-2:30
# 35                                          2:45-2:55
# 36                                          2:55-3:05
# 37                                          3:05-3:15
# 38                                          3:15-3:25
# 39                                          3:25-3:35
# 40                                          3:35-3:45
# 42               Wednesday morning session: community
# 43                                        10:00-10:10
# 44                                        10:10-10:20
# 45                                        10:20-10:30
# 46             Wednesday afternoon session: community
# 47                                        13:00-13:20
# 48                                        13:20-13:40
# 49                                        13:40-14:00
# 50                                        14:00-14:10
# 51                                        14:10-14:20
# 52                                        14:20-14:30
# 54                                            Posters
#
#                         type  \
# 0                        NaN
# 1        long-20' (talk+Q&A)
# 2        long-20' (talk+Q&A)
# 3        long-20' (talk+Q&A)
# 4   lightning-10' (talk+Q&A)
# 5   lightning-10' (talk+Q&A)
# 6   lightning-10' (talk+Q&A)
# 8                        NaN
# 9   lightning-10' (talk+Q&A)
# 10  lightning-10' (talk+Q&A)
# 11  lightning-10' (talk+Q&A)
# 12       long-20' (talk+Q&A)
# 13       long-20' (talk+Q&A)
# 14       long-20' (talk+Q&A)
# 15  lightning-10' (talk+Q&A)
# 16  lightning-10' (talk+Q&A)
# 17  lightning-10' (talk+Q&A)
# 19                       NaN
# 20       long-20' (talk+Q&A)
# 21       long-20' (talk+Q&A)
# 22       long-20' (talk+Q&A)
# 23  lightning-10' (talk+Q&A)
# 24  lightning-10' (talk+Q&A)
# 25  lightning-10' (talk+Q&A)
# 26  lightning-10' (talk+Q&A)
# 27  lightning-10' (talk+Q&A)
# 28  lightning-10' (talk+Q&A)
# 30                       NaN
# 31       long-20' (talk+Q&A)
# 32       long-20' (talk+Q&A)
# 33  lightning-10' (talk+Q&A)
# 34  lightning-10' (talk+Q&A)
# 35  lightning-10' (talk+Q&A)
# 36  lightning-10' (talk+Q&A)
# 37  lightning-10' (talk+Q&A)
# 38  lightning-10' (talk+Q&A)
# 39  lightning-10' (talk+Q&A)
# 40  lightning-10' (talk+Q&A)
# 42                       NaN
# 43  lightning-10' (talk+Q&A)
# 44  lightning-10' (talk+Q&A)
# 45  lightning-10' (talk+Q&A)
# 46                       NaN
# 47       long-20' (talk+Q&A)
# 48       long-20' (talk+Q&A)
# 49       long-20' (talk+Q&A)
# 50  lightning-10' (talk+Q&A)
# 51  lightning-10' (talk+Q&A)
# 52  lightning-10' (talk+Q&A)
# 54                       NaN
#
#                                               speaker  \
# 0                                                 NaN
# 1   Kalpana Panneerselvam, Pablo Porras, Noemi del...
# 2   Patrick Masson, Cristina Casals-Casas, Lionel ...
# 3   David Osumi-Sutherland, Robert Court, Huseyin ...
# 4   Qian Xiang, Edmund Su, Hardeep Nahal-Bose, Rob...
# 5   Marcela Tello-Ruiz, Nahla Bassil, Sebastian Be...
# 6   Yalan Bi, Nancy George, Irene Papatheodorou, A...
# 8                                                 NaN
# 9   Federica Quaglia, Damiano Piovesan, Silvio Tos...
# 10  Frederic B. Bastian, Vincent Gardeux, Bart Dep...
# 11              Christopher Southan and Miguel Amaral
# 12  Christopher Hunter, Chris Armit, Mary Ann Tuli...
# 13  J. Harry Caufield, Justin Reese, Tudor Oprea, ...
# 14  Lynn M Schriml, J. Allen Baron, Dustin Olley, ...
# 15                          Wei Kheng Teh and Fuqi Xu
# 16  Peter Woollard, Stephane Pesant, Josephine Bur...
# 17   Jerven Bolleman, Alan Bridge and Nicole Redaschi
# 19                                                NaN
# 20  Maria Victoria Nugnes, Federica Quaglia, Luigg...
# 21  Brian Alcock, Amogelang Raphenya, Arman Edalat...
# 22  Elisabeth Coudert, Sebastien Gehant, Nicole Re...
# 23  Simona Panni, Kalpana Panneerselvam, Pablo Por...
# 24  Leigh C Carmody, Michael Gargano, Nicole A Vas...
# 25  Dorotea Dudaš, Ulrike Wittig, Maja Rey, Andrea...
# 26  Amogelang Raphenya, Michael Surette, Gerard Wr...
# 27  Ziying Yang, Rahel Paloots, Hangjia Zhao and M...
# 28  Sandra Orchard, Birgit Meldal, Helen Attrill, ...
# 30                                                NaN
# 31  Valerio Arnaboldi, Daniela Raciti, Kimberly Va...
# 32  Jane Lomax, Rachael Huntley, Rebecca Foulger, ...
# 33  Carlos Vega, Marek Ostaszewski, Valentin Grouè...
# 34  Anne Niknejad, Vincent Gardeux, Fabrice David,...
# 35                                         Peter Uetz
# 36  Samir Gupta, Xihan Qin, Qinghua Wang, Julie Co...
# 37          Benjamin M. Gyori and Charles Tapley Hoyt
# 38  Emilie Pasche, Anaïs Mottaz, Julien Gobeill, P...
# 39  Rezarta Islamaj, Nicholas Miliaras, Olga Print...
# 40  Rossana Zaru, Vishal Joshi, Sandra Orchard and...
# 42                                                NaN
# 43  Marc Feuermann, Pascale Gaudet, Huaiyu Mi, Anu...
# 44  Catherine Hayes, Masaaki Shiota, Akihiro Fujit...
# 45                    Tiago Lubiana and Helder Nakaya
# 46                                                NaN
# 47          Charles Tapley Hoyt and Benjamin M. Gyori
# 48  Nancy George, Irene Papatheodorou, Anja Fullgr...
# 49                                   Arina Puzriakova
# 50  Marc Gillespie, Peter D'Eustachio, Robin Haw, ...
# 51  Irina Persikova, Jasmine Y. Young, Ezra Peisac...
# 52  Jennifer Harrow, Karyn Mégy, Amanda O'Neil, Ke...
# 54                                                NaN
#
#                                                 title      id
# 0                                                 NaN     NaN
# 1   Human-pathogen interaction networks: IMEx’s ap...  5380.0
# 2   Gene Ontology Causal Activity Models (GO-CAMs)...  6415.0
# 3                 The Knowledge Graph Development Kit  4113.0
# 4   ICGC-ARGO Data Submission Workflow - Integrati...  3601.0
# 5   Developing Standards for Biocuration & Interop...  8868.0
# 6    Multiplexed scRNA-seq Experiments in Biocuration  5715.0
# 8                                                 NaN     NaN
# 9   APICURON: standardizing attribution of biocura...   966.0
# 10  scFAIR: Standardization and stewardship of sin...  8261.0
# 11  Resolving code names to structures from the me...  8444.0
# 12  GigaDB: Utilising ontologies to curate data pu...  2885.0
# 13  KG-IDG: A FAIR Knowledge Graph for Illuminatin...   673.0
# 14  A 20 year perspective on FAIR and TRUST-worthy...   371.0
# 15  FAIR Wizard: Making the FAIRification process ...  9192.0
# 16  Providing Expanded Contextual Metadata for Bio...  4905.0
# 17        Making expert curated knowledge graphs FAIR  7142.0
# 19                                                NaN     NaN
# 20  Biocuration in DisProt, the manually curated d...  1006.0
# 21  The Comprehensive Antibiotic Resistance Databa...  7692.0
# 22  Annotation of biologically relevant ligands in...  2833.0
# 23  The landscape of microRNA interactions annotat...  7839.0
# 24  Medical Action Ontology (MAxO) development and...  1874.0
# 25  Improved Insights into the SABIO-RK Database v...  8451.0
# 26  The Human Microbiome Drug Metabolism (HMDM) Da...  6403.0
# 27  Phenopackets for curated repository data over ...  6778.0
# 28  Unifying Protein Complex Curation across the D...  6299.0
# 30                                                NaN     NaN
# 31  ACKnowledge: expanding community curation to i...  9967.0
# 32          Machine Learning for Scalable Biocuration  4380.0
# 33  BioKC: a collaborative platform for curation a...  6685.0
# 34  Building a reference dataset of single-cell RN...  9482.0
# 35  Curating species descriptions for the digital age  9553.0
# 36  eMIND: Enabling automatic collection of protei...  9773.0
# 37  Machine-assisted curation of molecular mechani...  9399.0
# 38  Assessing the Use of Supplementary Materials t...  9409.0
# 39  A Framework for Assisting MeSH Vocabulary Deve...  3753.0
# 40  Predicting protein metal binding sites with ar...   671.0
# 42                                                NaN     NaN
# 43  A complete draft human gene functionome from l...   885.0
# 44  Towards making sense of glycan-mediated protei...  7461.0
# 45   Wikidata as a tool for biocuration of cell types  8085.0
# 46                                                NaN     NaN
# 47  Promoting the longevity of curated scientific ...  6726.0
# 48  Single Cell Expression Atlas and FlyBase - the...   259.0
# 49  Leveraging crowdsourcing and curation prioriti...  5319.0
# 50  Community SARS-CoV-2 Curation Driven Emergent ...   796.0
# 51  wwPDB Biocuration: Supporting Advances in Scie...  4600.0
# 52  Accessing UK Biobank-derived data through the ...  7199.0
# 54                                                NaN     NaN

# %%
groups = defaultdict(list)
current_group_name = None

def fix_authors(s):
    return s.split(",")[0].strip().split(" and ")[0].strip()

def fix_type(s):
    if s == "long-20' (talk+Q&A)":
        return "long"
    if s == "lightning-10' (talk+Q&A)":
        return "lightning"
    raise ValueError(s)

    
def get_times(s):
    start_time, end_time = map(clean_time, map(str.strip, time.split("-")))
    return start_time, end_time
    
def clean_time(s):
    h, m = s.split(":")
    if int(h) <8:
        # print("old h", h, end=" ")
        h = str(int(h) + 12)
        # print("new h", h)
    return f"{h}.{m}"
    
    
columns =['time_start', 'time_end', 'type', 'speaker', 'title', 'id']
    
for time, talk_type, authors, title, idx in df.values:
    if not time[0].isdigit():
        current_group_name = time
        continue
    else:
        start_time, end_time = get_times(time)
        groups[current_group_name].append((
            start_time, end_time, fix_type(talk_type), fix_authors(authors), title, int(idx),
        ))

groups = {g: pd.DataFrame(l, columns=columns) for g, l in groups.items()}

# %%
info = {
    'Monday afternoon session: standards': dict(
        order=0,
        day="Monday",
        date="April 24th",
        start="16.30",
        end="18.00",
        title="Standards 1",
    ),
    'Tuesday morning session: FAIR': dict(
        order=1,
        day="Tuesday",
        date=" April 25th",
        start="10.00",
        end="12.30",
        title="FAIR 1",
    ), 

    'Tuesday afternoon session (parallel 1): applications': dict(
        order=2,
        day="Tuesday",
        date="April 25th",
        start="13.30",
        end="15.45",
        title="Applications 1",
    ), 
    'Tuesday afternoon session (parallel 2): AI and Text mining': dict(
        order=3,
        day="Tuesday",
        date="April 25th",
        start="13.30",
        end="15.45",
        title="AI and Text Mining 1",
    ),
    'Wednesday afternoon session: community': dict(
        order=4,
        day="Wednesday",
        date="April 26th",
        start="10.00",
        end="10.30",
        title="Community 1",
    ),
    'Wednesday morning session: community': dict(
        order=5,
        day="Wednesday",
        date="April 26th",
        start="13.00",
        end="14.30",
        title="Community 2",
    ),
}

# %%
rows = []
for key, data in sorted(info.items(), key=lambda e: e[1]["order"]):
    data["talks"] = groups[key].to_dict(orient="records")
    rows.append(data)
rows
# Out:
# [{'order': 0,
#   'day': 'Monday',
#   'date': 'April 24th',
#   'start': '16.30',
#   'end': '18.00',
#   'title': 'Standards 1',
#   'talks': [{'time_start': '16.30',
#     'time_end': '16.50',
#     'type': 'long',
#     'speaker': 'Kalpana Panneerselvam',
#     'title': 'Human-pathogen interaction networks: IMEx’s approach on the contextual metadata of the experimental evidence.',
#     'id': 5380},
#    {'time_start': '16.50',
#     'time_end': '17.10',
#     'type': 'long',
#     'speaker': 'Patrick Masson',
#     'title': 'Gene Ontology Causal Activity Models (GO-CAMs) for human biology',
#     'id': 6415},
#    {'time_start': '17.10',
#     'time_end': '17.30',
#     'type': 'long',
#     'speaker': 'David Osumi-Sutherland',
#     'title': 'The Knowledge Graph Development Kit',
#     'id': 4113},
#    {'time_start': '17.30',
#     'time_end': '17.40',
#     'type': 'lightning',
#     'speaker': 'Qian Xiang',
#     'title': 'ICGC-ARGO Data Submission Workflow - Integration of data validation and submission to accelerate the data curation and improve the data quality',
#     'id': 3601},
#    {'time_start': '17.40',
#     'time_end': '17.50',
#     'type': 'lightning',
#     'speaker': 'Marcela Tello-Ruiz',
#     'title': 'Developing Standards for Biocuration & Interoperability of Genetic Variation Data in Agricultural Research',
#     'id': 8868},
#    {'time_start': '17.50',
#     'time_end': '18.00',
#     'type': 'lightning',
#     'speaker': 'Yalan Bi',
#     'title': 'Multiplexed scRNA-seq Experiments in Biocuration',
#     'id': 5715}]},
#  {'order': 1,
#   'day': 'Tuesday',
#   'date': ' April 25th',
#   'start': '10.00',
#   'end': '12.30',
#   'title': 'FAIR 1',
#   'talks': [{'time_start': '10.00',
#     'time_end': '10.10',
#     'type': 'lightning',
#     'speaker': 'Federica Quaglia',
#     'title': 'APICURON: standardizing attribution of biocuration activity to promote engagement',
#     'id': 966},
#    {'time_start': '10.10',
#     'time_end': '10.20',
#     'type': 'lightning',
#     'speaker': 'Frederic B. Bastian',
#     'title': 'scFAIR: Standardization and stewardship of single-cell metadata',
#     'id': 8261},
#    {'time_start': '10.20',
#     'time_end': '10.30',
#     'type': 'lightning',
#     'speaker': 'Christopher Southan',
#     'title': 'Resolving code names to structures from the medicinal chemistry literature: not as FAIR as it should be',
#     'id': 8444},
#    {'time_start': '11.00',
#     'time_end': '11.20',
#     'type': 'long',
#     'speaker': 'Christopher Hunter',
#     'title': 'GigaDB: Utilising ontologies to curate data publications',
#     'id': 2885},
#    {'time_start': '11.20',
#     'time_end': '11.40',
#     'type': 'long',
#     'speaker': 'J. Harry Caufield',
#     'title': 'KG-IDG: A FAIR Knowledge Graph for Illuminating the Druggable Genome',
#     'id': 673},
#    {'time_start': '11.40',
#     'time_end': '12.00',
#     'type': 'long',
#     'speaker': 'Lynn M Schriml',
#     'title': 'A 20 year perspective on FAIR and TRUST-worthy Human Disease Knowledge Representation.',
#     'id': 371},
#    {'time_start': '12.00',
#     'time_end': '12.10',
#     'type': 'lightning',
#     'speaker': 'Wei Kheng Teh',
#     'title': 'FAIR Wizard: Making the FAIRification process accessible',
#     'id': 9192},
#    {'time_start': '12.10',
#     'time_end': '12.20',
#     'type': 'lightning',
#     'speaker': 'Peter Woollard',
#     'title': 'Providing Expanded Contextual Metadata for Biological Samples using Both Geographic and Taxonomic Factors',
#     'id': 4905},
#    {'time_start': '12.20',
#     'time_end': '12.30',
#     'type': 'lightning',
#     'speaker': 'Jerven Bolleman',
#     'title': 'Making expert curated knowledge graphs FAIR',
#     'id': 7142}]},
#  {'order': 2,
#   'day': 'Tuesday',
#   'date': 'April 25th',
#   'start': '13.30',
#   'end': '15.45',
#   'title': 'Applications 1',
#   'talks': [{'time_start': '13.30',
#     'time_end': '13.50',
#     'type': 'long',
#     'speaker': 'Maria Victoria Nugnes',
#     'title': 'Biocuration in DisProt, the manually curated database for intrinsically disordered proteins',
#     'id': 1006},
#    {'time_start': '13.50',
#     'time_end': '14.10',
#     'type': 'long',
#     'speaker': 'Brian Alcock',
#     'title': 'The Comprehensive Antibiotic Resistance Database - Curating the Global Resistome',
#     'id': 7692},
#    {'time_start': '14.10',
#     'time_end': '14.30',
#     'type': 'long',
#     'speaker': 'Elisabeth Coudert',
#     'title': 'Annotation of biologically relevant ligands in UniProtKB using ChEBI',
#     'id': 2833},
#    {'time_start': '14.45',
#     'time_end': '14.55',
#     'type': 'lightning',
#     'speaker': 'Simona Panni',
#     'title': 'The landscape of microRNA interactions annotation in IMEx: analysis of three rare disorders as case study',
#     'id': 7839},
#    {'time_start': '14.55',
#     'time_end': '15.05',
#     'type': 'lightning',
#     'speaker': 'Leigh C Carmody',
#     'title': 'Medical Action Ontology (MAxO) development and tool implementation for the annotation of Rare Disease (RD)',
#     'id': 1874},
#    {'time_start': '15.05',
#     'time_end': '15.15',
#     'type': 'lightning',
#     'speaker': 'Dorotea Dudaš',
#     'title': 'Improved Insights into the SABIO-RK Database via Visualization',
#     'id': 8451},
#    {'time_start': '15.15',
#     'time_end': '15.25',
#     'type': 'lightning',
#     'speaker': 'Amogelang Raphenya',
#     'title': 'The Human Microbiome Drug Metabolism (HMDM) Database',
#     'id': 6403},
#    {'time_start': '15.25',
#     'time_end': '15.35',
#     'type': 'lightning',
#     'speaker': 'Ziying Yang',
#     'title': 'Phenopackets for curated repository data over Beacon v2 Progenetix database',
#     'id': 6778},
#    {'time_start': '15.35',
#     'time_end': '15.45',
#     'type': 'lightning',
#     'speaker': 'Sandra Orchard',
#     'title': 'Unifying Protein Complex Curation across the Diversity of Species',
#     'id': 6299}]},
#  {'order': 3,
#   'day': 'Tuesday',
#   'date': 'April 25th',
#   'start': '13.30',
#   'end': '15.45',
#   'title': 'AI and Text Mining 1',
#   'talks': [{'time_start': '13.30',
#     'time_end': '13.50',
#     'type': 'long',
#     'speaker': 'Valerio Arnaboldi',
#     'title': 'ACKnowledge: expanding community curation to include fact extraction using artificial intelligence',
#     'id': 9967},
#    {'time_start': '13.50',
#     'time_end': '14.10',
#     'type': 'long',
#     'speaker': 'Jane Lomax',
#     'title': 'Machine Learning for Scalable Biocuration',
#     'id': 4380},
#    {'time_start': '14.10',
#     'time_end': '14.20',
#     'type': 'lightning',
#     'speaker': 'Carlos Vega',
#     'title': 'BioKC: a collaborative platform for curation and annotation of molecular interactions',
#     'id': 6685},
#    {'time_start': '14.20',
#     'time_end': '14.30',
#     'type': 'lightning',
#     'speaker': 'Anne Niknejad',
#     'title': 'Building a reference dataset of single-cell RNA-Seq data for training Machine-Learning algorithms',
#     'id': 9482},
#    {'time_start': '14.45',
#     'time_end': '14.55',
#     'type': 'lightning',
#     'speaker': 'Peter Uetz',
#     'title': 'Curating species descriptions for the digital age',
#     'id': 9553},
#    {'time_start': '14.55',
#     'time_end': '15.05',
#     'type': 'lightning',
#     'speaker': 'Samir Gupta',
#     'title': 'eMIND: Enabling automatic collection of protein variation impacts in Alzheimer’s disease from the literature',
#     'id': 9773},
#    {'time_start': '15.05',
#     'time_end': '15.15',
#     'type': 'lightning',
#     'speaker': 'Benjamin M. Gyori',
#     'title': 'Machine-assisted curation of molecular mechanisms using automated knowledge extraction and assembly',
#     'id': 9399},
#    {'time_start': '15.15',
#     'time_end': '15.25',
#     'type': 'lightning',
#     'speaker': 'Emilie Pasche',
#     'title': 'Assessing the Use of Supplementary Materials to Improve Genomic Variant Discovery',
#     'id': 9409},
#    {'time_start': '15.25',
#     'time_end': '15.35',
#     'type': 'lightning',
#     'speaker': 'Rezarta Islamaj',
#     'title': 'A Framework for Assisting MeSH Vocabulary Development at the National Library of Medicine: Reliably Identifying Literature Containing New Chemical Substances',
#     'id': 3753},
#    {'time_start': '15.35',
#     'time_end': '15.45',
#     'type': 'lightning',
#     'speaker': 'Rossana Zaru',
#     'title': 'Predicting protein metal binding sites with artificial intelligence and machine learning in UniProt',
#     'id': 671}]},
#  {'order': 4,
#   'day': 'Wednesday',
#   'date': 'April 26th',
#   'start': '10.00',
#   'end': '10.30',
#   'title': 'Community 1',
#   'talks': [{'time_start': '13.00',
#     'time_end': '13.20',
#     'type': 'long',
#     'speaker': 'Charles Tapley Hoyt',
#     'title': 'Promoting the longevity of curated scientific resources through open code, open data, and public infrastructure',
#     'id': 6726},
#    {'time_start': '13.20',
#     'time_end': '13.40',
#     'type': 'long',
#     'speaker': 'Nancy George',
#     'title': 'Single Cell Expression Atlas and FlyBase - the Fly Cell Atlas Anatomograms – where data meets art',
#     'id': 259},
#    {'time_start': '13.40',
#     'time_end': '14.00',
#     'type': 'long',
#     'speaker': 'Arina Puzriakova',
#     'title': 'Leveraging crowdsourcing and curation prioritisation for maintenance of clinical gene panels',
#     'id': 5319},
#    {'time_start': '14.00',
#     'time_end': '14.10',
#     'type': 'lightning',
#     'speaker': 'Marc Gillespie',
#     'title': 'Community SARS-CoV-2 Curation Driven Emergent Experiences - Increased Curation Efficiency and Learned Lessons for the Future',
#     'id': 796},
#    {'time_start': '14.10',
#     'time_end': '14.20',
#     'type': 'lightning',
#     'speaker': 'Irina Persikova',
#     'title': 'wwPDB Biocuration: Supporting Advances in Science and Technology',
#     'id': 4600},
#    {'time_start': '14.20',
#     'time_end': '14.30',
#     'type': 'lightning',
#     'speaker': 'Jennifer Harrow',
#     'title': 'Accessing UK Biobank-derived data through the AZ PheWAS portal, with reassigned phenotypic ICD10 codes.',
#     'id': 7199}]},
#  {'order': 5,
#   'day': 'Wednesday',
#   'date': 'April 26th',
#   'start': '13.00',
#   'end': '14.30',
#   'title': 'Community 2',
#   'talks': [{'time_start': '10.00',
#     'time_end': '10.10',
#     'type': 'lightning',
#     'speaker': 'Marc Feuermann',
#     'title': 'A complete draft human gene functionome from large-scale evolutionary modeling and experimental Gene Ontology annotations',
#     'id': 885},
#    {'time_start': '10.10',
#     'time_end': '10.20',
#     'type': 'lightning',
#     'speaker': 'Catherine Hayes',
#     'title': 'Towards making sense of glycan-mediated protein-protein interactions',
#     'id': 7461},
#    {'time_start': '10.20',
#     'time_end': '10.30',
#     'type': 'lightning',
#     'speaker': 'Tiago Lubiana',
#     'title': 'Wikidata as a tool for biocuration of cell types',
#     'id': 8085}]}]

# %%
with open('/Users/cthoyt/dev/biocuration2023.github.io/_data/sessions.yml', 'w') as file:
    yaml.safe_dump(rows, file, allow_unicode=True, sort_keys=True)
