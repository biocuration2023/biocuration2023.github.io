# %%
import pyalex
from pyalex import Works
import json
import pandas as pd
from collections import defaultdict

# %%
pyalex.config.email = "cthoyt@gmail.com"

usual_suspects = {
    "GB",  # Great Britian
    "US",  # USA
    "DE",  # Germany
    "IT",  # Italy
    "BE",  # Belgium
    "FI",  # Finland
    "CH",  # Switzerland
    "FR",  # France
    "ES",  # Spain
    "DK",  # Denmark
    "CZ",  # Czechia
    "CA",  # Canada
    "AU",  # Australia
    "SE",  # Sweden
    "HU",  # Hungary
    "PT",  # Portugal
    "NL",  # Netherlands
    "IE",  # Ireland
    "NO",  # Norway
    "CN",  # China
    "AT",  # Austria
}

def get_underrepresented_countries(work):
    dd = defaultdict(dict)
    for a in work['authorships']:
        for i in a['institutions']:
            iid = i.get('id')
            country_code = i.get('country_code')
            if not iid or not country_code or country_code in usual_suspects:
                continue
            iid = iid.removeprefix("https://openalex.org/")
            country_display = country_code_to_name[country_code]
            dd[country_display][iid] = i['display_name']
    return dict(dd)

# %%
country_code_to_name = {
    r['key']: r['key_display_name']
    for r in (
        Works()
        .filter(institutions={"is_global_south":True})
        .group_by("institutions.country_code")
        .get()
    )
}
len(country_code_to_name)
# Out:
# 200

# %%
results = defaultdict(dict)

def _append(works):
    for work in works:
        for country, institutions in get_underrepresented_countries(work).items():
            results[country][work['doi']] = institutions

# %%
issns = [
    "1758-0463", # Oxford Database
    "2041-1480", # Journal of Biomedical Semantics
]
for issn in issns:
    _append(
        Works()
        .filter(institutions={"is_global_south":True}, host_venue={"issn": issn})
        .get()
    )

# %%
keywords = [
    "biocuration",
    "biomedical ontology",
    "model organism database",
    "genomics database",
]
for keyword in keywords:
    _append(
        Works()
        .search(keyword)
        .filter(institutions={"is_global_south":True})
        .get()
    )

# %%
false_positives = {
    "https://doi.org/10.1093/nar/gkt1026", # HPO 2013 paper
    "https://doi.org/10.1186/2041-1480-2-s2-s1",
}
true_positives = {
    "https://doi.org/10.1186/s13326-016-0080-2", # Olaf Wolkenhauer had south africa affiliaton
    "https://doi.org/10.1111/nph.13557", # Yves Van de Peer has south africa affiliation
    "https://doi.org/10.1093/database/bau061", # Authors from many countries, but no disambiguation nor contact information available
}

df = pd.DataFrame(dict(results))
df = df[~df.index.isin(false_positives)]
df = df[~df.index.isin(true_positives)]
df
# Out:
#                                               Estonia Thailand  \
# https://doi.org/10.1186/s13326-015-0014-4         NaN      NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1         NaN      NaN
# https://doi.org/10.1186/s13326-018-0176-y         NaN      NaN
# https://doi.org/10.1093/nar/gkv350                NaN      NaN
# https://doi.org/10.1093/database/bar041           NaN      NaN
# ...                                               ...      ...
# https://doi.org/10.1093/nar/gki450                NaN      NaN
# https://doi.org/10.1007/978-3-319-49004-5_2       NaN      NaN
# https://doi.org/10.1145/3102254.3102284           NaN      NaN
# https://doi.org/10.1038/srep03376                 NaN      NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005     NaN      NaN
#
#                                                                            South Africa  \
# https://doi.org/10.1186/s13326-015-0014-4      {'I26092322': 'Stellenbosch University'}
# https://doi.org/10.1186/2041-1480-2-s2-s1                                           NaN
# https://doi.org/10.1186/s13326-018-0176-y                                           NaN
# https://doi.org/10.1093/nar/gkv350                                                  NaN
# https://doi.org/10.1093/database/bar041                                             NaN
# ...                                                                                 ...
# https://doi.org/10.1093/nar/gki450                                                  NaN
# https://doi.org/10.1007/978-3-319-49004-5_2                                         NaN
# https://doi.org/10.1145/3102254.3102284                                             NaN
# https://doi.org/10.1038/srep03376                                                   NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005                                       NaN
#
#                                                                                          Austria  \
# https://doi.org/10.1186/s13326-015-0014-4                                                    NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1      {'I5994924': 'Information Retrieval Facility',...
# https://doi.org/10.1186/s13326-018-0176-y                                                    NaN
# https://doi.org/10.1093/nar/gkv350                                                           NaN
# https://doi.org/10.1093/database/bar041                                                      NaN
# ...                                                                                          ...
# https://doi.org/10.1093/nar/gki450                                                           NaN
# https://doi.org/10.1007/978-3-319-49004-5_2                                                  NaN
# https://doi.org/10.1145/3102254.3102284                                                      NaN
# https://doi.org/10.1038/srep03376                                                            NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005                                                NaN
#
#                                                                         Korea, Republic of  \
# https://doi.org/10.1186/s13326-015-0014-4                                              NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1                   {'I4210092243': 'AstraZeneca'}
# https://doi.org/10.1186/s13326-018-0176-y                {'I191879574': 'Inha University'}
# https://doi.org/10.1093/nar/gkv350             {'I139264467': 'Seoul National University'}
# https://doi.org/10.1093/database/bar041                                                NaN
# ...                                                                                    ...
# https://doi.org/10.1093/nar/gki450                                                     NaN
# https://doi.org/10.1007/978-3-319-49004-5_2                                            NaN
# https://doi.org/10.1145/3102254.3102284                                                NaN
# https://doi.org/10.1038/srep03376                                                      NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005                                          NaN
#
#                                               New Zealand  \
# https://doi.org/10.1186/s13326-015-0014-4             NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1             NaN
# https://doi.org/10.1186/s13326-018-0176-y             NaN
# https://doi.org/10.1093/nar/gkv350                    NaN
# https://doi.org/10.1093/database/bar041               NaN
# ...                                                   ...
# https://doi.org/10.1093/nar/gki450                    NaN
# https://doi.org/10.1007/978-3-319-49004-5_2           NaN
# https://doi.org/10.1145/3102254.3102284               NaN
# https://doi.org/10.1038/srep03376                     NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005         NaN
#
#                                                                               Japan  \
# https://doi.org/10.1186/s13326-015-0014-4                                       NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1                                       NaN
# https://doi.org/10.1186/s13326-018-0176-y                                       NaN
# https://doi.org/10.1093/nar/gkv350                                              NaN
# https://doi.org/10.1093/database/bar041        {'I74801974': 'University of Tokyo'}
# ...                                                                             ...
# https://doi.org/10.1093/nar/gki450                                              NaN
# https://doi.org/10.1007/978-3-319-49004-5_2                                     NaN
# https://doi.org/10.1145/3102254.3102284                                         NaN
# https://doi.org/10.1038/srep03376                                               NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005                                   NaN
#
#                                               India  \
# https://doi.org/10.1186/s13326-015-0014-4       NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1       NaN
# https://doi.org/10.1186/s13326-018-0176-y       NaN
# https://doi.org/10.1093/nar/gkv350              NaN
# https://doi.org/10.1093/database/bar041         NaN
# ...                                             ...
# https://doi.org/10.1093/nar/gki450              NaN
# https://doi.org/10.1007/978-3-319-49004-5_2     NaN
# https://doi.org/10.1145/3102254.3102284         NaN
# https://doi.org/10.1038/srep03376               NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005   NaN
#
#                                                                                          Peru  \
# https://doi.org/10.1186/s13326-015-0014-4                                                 NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1                                                 NaN
# https://doi.org/10.1186/s13326-018-0176-y                                                 NaN
# https://doi.org/10.1093/nar/gkv350             {'I1318233029': 'International Potato Center'}
# https://doi.org/10.1093/database/bar041        {'I1318233029': 'International Potato Center'}
# ...                                                                                       ...
# https://doi.org/10.1093/nar/gki450                                                        NaN
# https://doi.org/10.1007/978-3-319-49004-5_2                                               NaN
# https://doi.org/10.1145/3102254.3102284                                                   NaN
# https://doi.org/10.1038/srep03376                                                         NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005                                             NaN
#
#                                               Iran, Islamic Republic of  ...  \
# https://doi.org/10.1186/s13326-015-0014-4                           NaN  ...
# https://doi.org/10.1186/2041-1480-2-s2-s1                           NaN  ...
# https://doi.org/10.1186/s13326-018-0176-y                           NaN  ...
# https://doi.org/10.1093/nar/gkv350                                  NaN  ...
# https://doi.org/10.1093/database/bar041                             NaN  ...
# ...                                                                 ...  ...
# https://doi.org/10.1093/nar/gki450                                  NaN  ...
# https://doi.org/10.1007/978-3-319-49004-5_2                         NaN  ...
# https://doi.org/10.1145/3102254.3102284                             NaN  ...
# https://doi.org/10.1038/srep03376                                   NaN  ...
# https://doi.org/10.1016/j.aquatox.2007.04.005                       NaN  ...
#
#                                               Costa Rica Poland Greece  \
# https://doi.org/10.1186/s13326-015-0014-4            NaN    NaN    NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1            NaN    NaN    NaN
# https://doi.org/10.1186/s13326-018-0176-y            NaN    NaN    NaN
# https://doi.org/10.1093/nar/gkv350                   NaN    NaN    NaN
# https://doi.org/10.1093/database/bar041              NaN    NaN    NaN
# ...                                                  ...    ...    ...
# https://doi.org/10.1093/nar/gki450                   NaN    NaN    NaN
# https://doi.org/10.1007/978-3-319-49004-5_2          NaN    NaN    NaN
# https://doi.org/10.1145/3102254.3102284              NaN    NaN    NaN
# https://doi.org/10.1038/srep03376                    NaN    NaN    NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005        NaN    NaN    NaN
#
#                                                                                         Ethiopia  \
# https://doi.org/10.1186/s13326-015-0014-4                                                    NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1                                                    NaN
# https://doi.org/10.1186/s13326-018-0176-y                                                    NaN
# https://doi.org/10.1093/nar/gkv350                                                           NaN
# https://doi.org/10.1093/database/bar041                                                      NaN
# ...                                                                                          ...
# https://doi.org/10.1093/nar/gki450             {'I2802457231': 'New Generation University Col...
# https://doi.org/10.1007/978-3-319-49004-5_2                                                  NaN
# https://doi.org/10.1145/3102254.3102284                                                      NaN
# https://doi.org/10.1038/srep03376                                                            NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005                                                NaN
#
#                                                                                          Algeria  \
# https://doi.org/10.1186/s13326-015-0014-4                                                    NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1                                                    NaN
# https://doi.org/10.1186/s13326-018-0176-y                                                    NaN
# https://doi.org/10.1093/nar/gkv350                                                           NaN
# https://doi.org/10.1093/database/bar041                                                      NaN
# ...                                                                                          ...
# https://doi.org/10.1093/nar/gki450                                                           NaN
# https://doi.org/10.1007/978-3-319-49004-5_2    {'I4210149016': 'École Nationale Supérieure d'...
# https://doi.org/10.1145/3102254.3102284                                                      NaN
# https://doi.org/10.1038/srep03376                                                            NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005                                                NaN
#
#                                                                           Tunisia  \
# https://doi.org/10.1186/s13326-015-0014-4                                     NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1                                     NaN
# https://doi.org/10.1186/s13326-018-0176-y                                     NaN
# https://doi.org/10.1093/nar/gkv350                                            NaN
# https://doi.org/10.1093/database/bar041                                       NaN
# ...                                                                           ...
# https://doi.org/10.1093/nar/gki450                                            NaN
# https://doi.org/10.1007/978-3-319-49004-5_2                                   NaN
# https://doi.org/10.1145/3102254.3102284        {'I108714496': 'Tunis University'}
# https://doi.org/10.1038/srep03376                                             NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005                                 NaN
#
#                                                                                            Fiji  \
# https://doi.org/10.1186/s13326-015-0014-4                                                   NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1                                                   NaN
# https://doi.org/10.1186/s13326-018-0176-y                                                   NaN
# https://doi.org/10.1093/nar/gkv350                                                          NaN
# https://doi.org/10.1093/database/bar041                                                     NaN
# ...                                                                                         ...
# https://doi.org/10.1093/nar/gki450                                                          NaN
# https://doi.org/10.1007/978-3-319-49004-5_2                                                 NaN
# https://doi.org/10.1145/3102254.3102284                                                     NaN
# https://doi.org/10.1038/srep03376              {'I44666525': 'University of the South Pacific'}
# https://doi.org/10.1016/j.aquatox.2007.04.005                                               NaN
#
#                                               Colombia Romania  \
# https://doi.org/10.1186/s13326-015-0014-4          NaN     NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1          NaN     NaN
# https://doi.org/10.1186/s13326-018-0176-y          NaN     NaN
# https://doi.org/10.1093/nar/gkv350                 NaN     NaN
# https://doi.org/10.1093/database/bar041            NaN     NaN
# ...                                                ...     ...
# https://doi.org/10.1093/nar/gki450                 NaN     NaN
# https://doi.org/10.1007/978-3-319-49004-5_2        NaN     NaN
# https://doi.org/10.1145/3102254.3102284            NaN     NaN
# https://doi.org/10.1038/srep03376                  NaN     NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005      NaN     NaN
#
#                                                                                      Puerto Rico
# https://doi.org/10.1186/s13326-015-0014-4                                                    NaN
# https://doi.org/10.1186/2041-1480-2-s2-s1                                                    NaN
# https://doi.org/10.1186/s13326-018-0176-y                                                    NaN
# https://doi.org/10.1093/nar/gkv350                                                           NaN
# https://doi.org/10.1093/database/bar041                                                      NaN
# ...                                                                                          ...
# https://doi.org/10.1093/nar/gki450                                                           NaN
# https://doi.org/10.1007/978-3-319-49004-5_2                                                  NaN
# https://doi.org/10.1145/3102254.3102284                                                      NaN
# https://doi.org/10.1038/srep03376                                                            NaN
# https://doi.org/10.1016/j.aquatox.2007.04.005  {'I26005898': 'UPRRP College of Natural Scienc...
#
# [77 rows x 37 columns]

# %%
r = []
for work in w:
    title = work['title']
    dd = defaultdict(dict)
    authors = []
    for a in work['authorships']:
        countries = []
        for i in a['institutions']:
            iid = i.get('id')
            country_code = i.get('country_code')
            if not iid or not country_code or country_code in usual_suspects:
                continue
            iid = iid.removeprefix("https://openalex.org/")
            country_display = country_code_to_name[country_code]
            countries.append(country_display)
            dd[f'{country_display} ({country_code})'][iid] = i['display_name']
        if not countries:
            continue
        
        # THIS WORKS BADLY
        author = a['author']
        author_id = author['id']
        if author_id:
            author_id = author_id.removeprefix("https://openalex.org/")
        author_dict = dict(
            openalex=author_id,
            name=author.get('display_name'),
            countries=countries,
        )
        orcid = author.get("orcid")
        if orcid:
            author_dict['orcid'] = orcid.removeprefix("https://orcid.org/")
        authors.append(author_dict)
    r.append(dict(
        id=work['id'],
        title=title, 
        # institutions=dict(dd), 
        authors=authors,
    ))

print(json.dumps(r, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "id": "https://openalex.org/W2168644196",
#     "title": "Text-mining-assisted biocuration workflows in Argo",
#     "authors": [
#       {
#         "openalex": "A2158507047",
#         "name": "Rafal Rak",
#         "countries": [
#           "Philippines"
#         ]
#       },
#       {
#         "openalex": "A2160147828",
#         "name": "Andrew F. Rowley",
#         "countries": [
#           "Philippines"
#         ]
#       },
#       {
#         "openalex": "A2130666468",
#         "name": "Jacob Carter",
#         "countries": [
#           "Philippines"
#         ]
#       },
#       {
#         "openalex": "A2141504082",
#         "name": "Sophia Ananiadou",
#         "countries": [
#           "Philippines"
#         ],
#         "orcid": "0000-0002-4097-9191"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W1980075500",
#     "title": "Bringing Biocuration to China",
#     "authors": [
#       {
#         "openalex": "A2170102332",
#         "name": "Zhang Zhang",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-6603-5060"
#       },
#       {
#         "openalex": "A2965461387",
#         "name": "Weimin Zhu",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2012658727",
#         "name": "Jingchu Luo",
#         "countries": [
#           "China"
#         ]
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2097456924",
#     "title": "Developing a biocuration workflow for AgBase, a non-model organism database",
#     "authors": [
#       {
#         "openalex": "A1796085180",
#         "name": "Philippe Chouvarine",
#         "countries": [
#           "Chile"
#         ],
#         "orcid": "0000-0003-0563-315X"
#       },
#       {
#         "openalex": "A2075257882",
#         "name": "Catalina O. Tudor",
#         "countries": [
#           "Chile"
#         ]
#       },
#       {
#         "openalex": "A2121571163",
#         "name": "Carl Schmidt",
#         "countries": [
#           "Chile"
#         ],
#         "orcid": "0000-0001-6126-8789"
#       },
#       {
#         "openalex": "A2700688118",
#         "name": "K. Vijay-Shanker",
#         "countries": [
#           "Chile"
#         ]
#       },
#       {
#         "openalex": "A2036408155",
#         "name": "Fiona M. McCarthy",
#         "countries": [
#           "Chile"
#         ],
#         "orcid": "0000-0003-2175-5464"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2166240318",
#     "title": "An overview of the BioCreative 2012 Workshop Track III: interactive text mining task",
#     "authors": [
#       {
#         "openalex": "A1989027375",
#         "name": "Petra Fey",
#         "countries": [
#           "Philippines"
#         ]
#       },
#       {
#         "openalex": "A2149168060",
#         "name": "Robert J. Dodson",
#         "countries": [
#           "Philippines"
#         ]
#       },
#       {
#         "openalex": "A2112080711",
#         "name": "Marc Gillespie",
#         "countries": [
#           "Taiwan, Province of China"
#         ],
#         "orcid": "0000-0002-5766-1702"
#       },
#       {
#         "openalex": "A2411731344",
#         "name": "Johnny Wu",
#         "countries": [
#           "Taiwan, Province of China"
#         ]
#       },
#       {
#         "openalex": "A2606768127",
#         "name": "Kalpana Raja",
#         "countries": [
#           "India"
#         ]
#       },
#       {
#         "openalex": "A1978634616",
#         "name": "Suresh Subramani",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0002-7728-7164"
#       },
#       {
#         "openalex": "A2061036276",
#         "name": "Jeyakumar Natarajan",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0003-3981-619X"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2989608901",
#     "title": "The CAFA challenge reports improved protein function prediction and new functional annotations for hundreds of genes through experimental screens",
#     "authors": [
#       {
#         "openalex": "A2294372490",
#         "name": "Tunca Doğan",
#         "countries": [
#           "Turkey"
#         ],
#         "orcid": "0000-0002-1298-9763"
#       },
#       {
#         "openalex": "A1627015213",
#         "name": "Volkan Atalay",
#         "countries": [
#           "Turkey"
#         ],
#         "orcid": "0000-0001-7850-0601"
#       },
#       {
#         "openalex": "A2222976677",
#         "name": "Ahmet Sureyya Rifaioglu",
#         "countries": [
#           "Turkey"
#         ],
#         "orcid": "0000-0001-6717-4767"
#       },
#       {
#         "openalex": "A2892114189",
#         "name": "Alperen Dalkiran",
#         "countries": [
#           "Turkey"
#         ]
#       },
#       {
#         "openalex": "A2008777834",
#         "name": "Rengul Cetin-Atalay",
#         "countries": [
#           "Turkey"
#         ],
#         "orcid": "0000-0003-2408-6606"
#       },
#       {
#         "openalex": "A2013406946",
#         "name": "Branislava Gemovic",
#         "countries": [
#           "Serbia"
#         ],
#         "orcid": "0000-0001-6899-3043"
#       },
#       {
#         "openalex": "A1984769747",
#         "name": "Vladimir Perovic",
#         "countries": [
#           "Serbia"
#         ],
#         "orcid": "0000-0002-3700-6452"
#       },
#       {
#         "openalex": "A2129137781",
#         "name": "Radoslav Davidovic",
#         "countries": [
#           "Serbia"
#         ]
#       },
#       {
#         "openalex": "A2557628388",
#         "name": "Neven Sumonja",
#         "countries": [
#           "Serbia"
#         ]
#       },
#       {
#         "openalex": "A1997854003",
#         "name": "Nevena Veljkovic",
#         "countries": [
#           "Serbia"
#         ],
#         "orcid": "0000-0001-6562-5800"
#       },
#       {
#         "openalex": "A1677516344",
#         "name": "Itamar Borukhov",
#         "countries": [
#           "Israel"
#         ]
#       },
#       {
#         "openalex": "A3001070082",
#         "name": "Po-Han Chi",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2648023924",
#         "name": "Wei-Cheng Tseng",
#         "countries": [
#           "Taiwan, Province of China"
#         ],
#         "orcid": "0000-0003-3528-8633"
#       },
#       {
#         "openalex": "A2244668935",
#         "name": "Michal Linial",
#         "countries": [
#           "Israel"
#         ],
#         "orcid": "0000-0002-9357-4526"
#       },
#       {
#         "openalex": "A2701303639",
#         "name": "Vedrana Vidulin",
#         "countries": [
#           "Slovenia"
#         ]
#       },
#       {
#         "openalex": "A1419022840",
#         "name": "Sašo Džeroski",
#         "countries": [
#           "Slovenia"
#         ],
#         "orcid": "0000-0003-2363-712X"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W1973424926",
#     "title": "STIFDB2: An Updated Version of Plant Stress-Responsive TranscrIption Factor DataBase with Additional Stress Signals, Stress-Responsive Transcription Factor Binding Sites and Stress-Responsive Genes in Arabidopsis and Rice",
#     "authors": [
#       {
#         "openalex": "A1989142116",
#         "name": "Mahantesha B.N. Naika",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0003-0753-792X"
#       },
#       {
#         "openalex": "A1871444660",
#         "name": "Khader Shameer",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0002-9982-1911"
#       },
#       {
#         "openalex": "A2674304002",
#         "name": "Oommen P. Mathew",
#         "countries": [
#           "India"
#         ]
#       },
#       {
#         "openalex": "A3082310333",
#         "name": "Ramanjini Gowda Ph",
#         "countries": [
#           "India"
#         ]
#       },
#       {
#         "openalex": "A2271892864",
#         "name": "Ramanathan Sowdhamini",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0002-6642-2367"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W3044926932",
#     "title": "CNSA: a data repository for archiving omics data",
#     "authors": [
#       {
#         "openalex": "A2658820073",
#         "name": "Xueqin Guo",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A3033446275",
#         "name": "Fengzhen Chen",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2163705068",
#         "name": "Fei Gao",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-6739-5076"
#       },
#       {
#         "openalex": "A2606725015",
#         "name": "Ling Li",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-8725-1221"
#       },
#       {
#         "openalex": "A2638135943",
#         "name": "Ke Liu",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-9812-4172"
#       },
#       {
#         "openalex": "A3033142942",
#         "name": "Lijin You",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2119398962",
#         "name": "Cong Hua",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2225695481",
#         "name": "Fan Yang",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-5404-0567"
#       },
#       {
#         "openalex": "A2789439127",
#         "name": "Wanliang Liu",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0003-3195-4598"
#       },
#       {
#         "openalex": "A2169520077",
#         "name": "Chunhua Peng",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2105491221",
#         "name": "Lina Wang",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2608860727",
#         "name": "Xiaoxia Yang",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-0670-053X"
#       },
#       {
#         "openalex": "A2120778392",
#         "name": "F.Y. Zhou",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2978289717",
#         "name": "Jiawei Tong",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2358588767",
#         "name": "Jia Cai",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-9501-7336"
#       },
#       {
#         "openalex": "A2170463797",
#         "name": "Zhiyong Li",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-9778-6158"
#       },
#       {
#         "openalex": "A2233816822",
#         "name": "Bo Wan",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-5896-9485"
#       },
#       {
#         "openalex": "A2299437103",
#         "name": "Lei Zhang",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-9677-120X"
#       },
#       {
#         "openalex": "A2557936967",
#         "name": "Tao Yang",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-4053-124X"
#       },
#       {
#         "openalex": "A2588238583",
#         "name": "Minwen Zhang",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2246446201",
#         "name": "Linlin Yang",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-5602-4157"
#       },
#       {
#         "openalex": "A2251700687",
#         "name": "Ya-wen Yang",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2918252613",
#         "name": "Wenjun Zeng",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0003-2531-3137"
#       },
#       {
#         "openalex": "A2720046968",
#         "name": "Bo Wang",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-9755-498X"
#       },
#       {
#         "openalex": "A2138616005",
#         "name": "Xiaofeng Wei",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2570467540",
#         "name": "Xun Xu",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-5338-5173"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W3214870576",
#     "title": "DisProt in 2022: improved quality and accessibility of protein intrinsic disorder annotation",
#     "authors": [
#       {
#         "openalex": "A1245794347",
#         "name": "Lucía B. Chemes",
#         "countries": [
#           "Argentina"
#         ],
#         "orcid": "0000-0003-0192-9906"
#       },
#       {
#         "openalex": "A2129137781",
#         "name": "Radoslav Davidovic",
#         "countries": [
#           "Serbia"
#         ]
#       },
#       {
#         "openalex": "A2052847214",
#         "name": "Juliana Glavina",
#         "countries": [
#           "Argentina"
#         ],
#         "orcid": "0000-0001-6336-1290"
#       },
#       {
#         "openalex": "A1986794220",
#         "name": "Javier Iserte",
#         "countries": [
#           "Argentina"
#         ]
#       },
#       {
#         "openalex": "A2901084645",
#         "name": "Julia Marchetti",
#         "countries": [
#           "Argentina"
#         ],
#         "orcid": "0000-0002-2886-3647"
#       },
#       {
#         "openalex": "A2492108859",
#         "name": "Cristina Marino-Buslje",
#         "countries": [
#           "Argentina"
#         ],
#         "orcid": "0000-0002-6564-1920"
#       },
#       {
#         "openalex": "A2412536469",
#         "name": "Nicolas Palopoli",
#         "countries": [
#           "Argentina"
#         ],
#         "orcid": "0000-0001-7925-6436"
#       },
#       {
#         "openalex": "A2039733517",
#         "name": "Vasilis J. Promponas",
#         "countries": [
#           "Cyprus"
#         ],
#         "orcid": "0000-0003-3352-4831"
#       },
#       {
#         "openalex": "A3211643755",
#         "name": "Martín N. Salas",
#         "countries": [
#           "Argentina"
#         ]
#       },
#       {
#         "openalex": "A2073374177",
#         "name": "Luciana Rodriguez Sawicki",
#         "countries": [
#           "Argentina"
#         ]
#       },
#       {
#         "openalex": "A1997854003",
#         "name": "Nevena Veljkovic",
#         "countries": [
#           "Serbia"
#         ],
#         "orcid": "0000-0001-6562-5800"
#       },
#       {
#         "openalex": "A1980579513",
#         "name": "Gustavo Parisi",
#         "countries": [
#           "Argentina"
#         ],
#         "orcid": "0000-0001-7444-1624"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2334487059",
#     "title": "Chemical-induced disease relation extraction with various linguistic features",
#     "authors": [
#       {
#         "openalex": "A2324118674",
#         "name": "Jinghang Gu",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-6335-0433"
#       },
#       {
#         "openalex": "A2120211867",
#         "name": "Longhua Qian",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2147795187",
#         "name": "Guodong Zhou",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0003-1458-103X"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2516150684",
#     "title": "Overview of the interactive task in BioCreative V",
#     "authors": [
#       {
#         "openalex": "A2084713166",
#         "name": "Shabbir Syed-Abdul",
#         "countries": [
#           "Taiwan, Province of China"
#         ],
#         "orcid": "0000-0002-0412-767X"
#       },
#       {
#         "openalex": "A1489998975",
#         "name": "Yalbi I. Balderas-Martínez",
#         "countries": [
#           "Mexico"
#         ],
#         "orcid": "0000-0001-6400-0526"
#       },
#       {
#         "openalex": "A2162697446",
#         "name": "Gabriela Navarro Contreras",
#         "countries": [
#           "Mexico"
#         ],
#         "orcid": "0000-0003-4744-2351"
#       },
#       {
#         "openalex": "A2162897294",
#         "name": "Hongjie Dai",
#         "countries": [
#           "Taiwan, Province of China"
#         ],
#         "orcid": "0000-0001-8829-4776"
#       },
#       {
#         "openalex": "A326640264",
#         "name": "Socorro Gama-Castro",
#         "countries": [
#           "Mexico"
#         ]
#       },
#       {
#         "openalex": "A2061036276",
#         "name": "Jeyakumar Natarajan",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0003-3981-619X"
#       },
#       {
#         "openalex": "A2147310660",
#         "name": "Onkar Singh",
#         "countries": [
#           "Taiwan, Province of China"
#         ],
#         "orcid": "0000-0002-0910-2244"
#       },
#       {
#         "openalex": "A2962943079",
#         "name": "Chu-Hsien Su",
#         "countries": [
#           "Taiwan, Province of China"
#         ]
#       },
#       {
#         "openalex": "A1978634616",
#         "name": "Suresh Subramani",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0002-7728-7164"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2782155089",
#     "title": "Multi-label Deep Learning for Gene Function Annotation in Cancer Pathways",
#     "authors": [
#       {
#         "openalex": "A2098160485",
#         "name": "Renchu Guan",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-7162-7826"
#       },
#       {
#         "openalex": "A2433613717",
#         "name": "Lei Wang",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2701680931",
#         "name": "Yu Zhang",
#         "countries": [
#           "China",
#           "China"
#         ],
#         "orcid": "0000-0001-7029-396X"
#       },
#       {
#         "openalex": "A2166884690",
#         "name": "Fengfeng Zhou",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-8108-6007"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2122496897",
#     "title": "Overview of the ID, EPI and REL tasks of BioNLP Shared Task 2011",
#     "authors": [
#       {
#         "openalex": "A2105915347",
#         "name": "Tomoko Ohta",
#         "countries": [
#           "Japan"
#         ]
#       },
#       {
#         "openalex": "A710867540",
#         "name": "Jun'ichi Tsujii",
#         "countries": [
#           "China"
#         ]
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W1981532676",
#     "title": "Challenges of the next decade for the Asia Pacific region: 2010 International Conference in Bioinformatics (InCoB 2010)",
#     "authors": [
#       {
#         "openalex": "A2116731834",
#         "name": "Shoba Ranganathan",
#         "countries": [
#           "Singapore"
#         ],
#         "orcid": "0000-0002-8290-813X"
#       },
#       {
#         "openalex": "A2063970254",
#         "name": "Christian Schönbach",
#         "countries": [
#           "Japan"
#         ]
#       },
#       {
#         "openalex": "A1976656464",
#         "name": "Kenta Nakai",
#         "countries": [
#           "Japan"
#         ],
#         "orcid": "0000-0002-8721-8883"
#       },
#       {
#         "openalex": "A2170850377",
#         "name": "Tin Wee Tan",
#         "countries": [
#           "Singapore"
#         ]
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2607951264",
#     "title": "ChloroKB: A Web Application for the Integration of Knowledge Related to Chloroplast Metabolic Network",
#     "authors": [
#       {
#         "openalex": "A2297254488",
#         "name": "Michel Matringe",
#         "countries": [
#           "Morocco"
#         ],
#         "orcid": "0000-0001-8554-0863"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W1968095293",
#     "title": "Manually curated database of rice proteins",
#     "authors": [
#       {
#         "openalex": "A2519282102",
#         "name": "Pratibha Gour",
#         "countries": [
#           "India"
#         ]
#       },
#       {
#         "openalex": "A2513759728",
#         "name": "Priyanka Garg",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0002-9852-929X"
#       },
#       {
#         "openalex": "A2145323828",
#         "name": "Rashmi Jain",
#         "countries": [
#           "India"
#         ]
#       },
#       {
#         "openalex": "A2100195938",
#         "name": "Shaji Joseph",
#         "countries": [
#           "India"
#         ]
#       },
#       {
#         "openalex": "A2231660400",
#         "name": "Akhilesh K. Tyagi",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0001-9096-7116"
#       },
#       {
#         "openalex": "A2051056115",
#         "name": "Saurabh Raghuvanshi",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0002-8349-4290"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W3199802768",
#     "title": "Plant lectins and their many roles: Carbohydrate-binding and beyond",
#     "authors": [
#       {
#         "openalex": "A159429615",
#         "name": "Sneha Sudha Komath",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0002-0491-7102"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2783825348",
#     "title": "Genomic repeats, misassembly and reannotation: a case study with long-read resequencing of Porphyromonas gingivalis reference strains",
#     "authors": [
#       {
#         "openalex": "A216829975",
#         "name": "Luis Acuña-Amador",
#         "countries": [
#           "Costa Rica"
#         ]
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2346452181",
#     "title": "BioCreative V CDR task corpus: a resource for chemical disease relation extraction",
#     "authors": [
#       {
#         "openalex": "A2138582956",
#         "name": "Jiao Li",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2129014936",
#         "name": "Yueping Sun",
#         "countries": [
#           "China"
#         ]
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2335791510",
#     "title": "Assessing the state of the art in biomedical relation extraction: overview of the BioCreative V chemical-disease relation (CDR) task",
#     "authors": [
#       {
#         "openalex": "A2138582956",
#         "name": "Jiao Li",
#         "countries": [
#           "China"
#         ]
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2227395312",
#     "title": "An expanded evaluation of protein function prediction methods shows an improvement in accuracy",
#     "authors": [
#       {
#         "openalex": "A2133397212",
#         "name": "Ching-Tai Chen",
#         "countries": [
#           "Taiwan, Province of China"
#         ],
#         "orcid": "0000-0001-5695-1962"
#       },
#       {
#         "openalex": "A2468435316",
#         "name": "Wen-Lian Hsu",
#         "countries": [
#           "Taiwan, Province of China"
#         ]
#       },
#       {
#         "openalex": "A1977749361",
#         "name": "Dan Ofer",
#         "countries": [
#           "Israel"
#         ],
#         "orcid": "0000-0001-5136-8014"
#       },
#       {
#         "openalex": "A1971142394",
#         "name": "Nadav Rappoport",
#         "countries": [
#           "Israel"
#         ],
#         "orcid": "0000-0002-7218-2558"
#       },
#       {
#         "openalex": "A2510517895",
#         "name": "Amos Stern",
#         "countries": [
#           "Israel"
#         ]
#       },
#       {
#         "openalex": "A147526709",
#         "name": "Tamás Nepusz",
#         "countries": [
#           "Norway"
#         ],
#         "orcid": "0000-0002-1451-338X"
#       },
#       {
#         "openalex": "A2581123571",
#         "name": "Qingtian Gong",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0003-3095-0309"
#       },
#       {
#         "openalex": "A2129449873",
#         "name": "Wei Ning",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-7545-3632"
#       },
#       {
#         "openalex": "A2344840347",
#         "name": "Yuanpeng Zhou",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2190535493",
#         "name": "Weidong Tian",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0003-0175-1132"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2074162075",
#     "title": "Biological Databases for Human Research",
#     "authors": [
#       {
#         "openalex": "A2236532467",
#         "name": "Dong Zou",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0002-7169-4965"
#       },
#       {
#         "openalex": "A2124593669",
#         "name": "Lina Ma",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-7630-6960"
#       },
#       {
#         "openalex": "A2144260202",
#         "name": "Jun Yu",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-5673-620X"
#       },
#       {
#         "openalex": "A2170102332",
#         "name": "Zhang Zhang",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-6603-5060"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2947872911",
#     "title": "The CAFA challenge reports improved protein function prediction and new functional annotations for hundreds of genes through experimental screens",
#     "authors": [
#       {
#         "openalex": "A2294372490",
#         "name": "Tunca Doğan",
#         "countries": [
#           "Turkey"
#         ],
#         "orcid": "0000-0002-1298-9763"
#       },
#       {
#         "openalex": "A1627015213",
#         "name": "Volkan Atalay",
#         "countries": [
#           "Turkey"
#         ],
#         "orcid": "0000-0001-7850-0601"
#       },
#       {
#         "openalex": "A2222976677",
#         "name": "Ahmet Sureyya Rifaioglu",
#         "countries": [
#           "Turkey"
#         ],
#         "orcid": "0000-0001-6717-4767"
#       },
#       {
#         "openalex": "A2892114189",
#         "name": "Alperen Dalkiran",
#         "countries": [
#           "Turkey"
#         ]
#       },
#       {
#         "openalex": "A2008777834",
#         "name": "Rengul Cetin-Atalay",
#         "countries": [
#           "Turkey"
#         ],
#         "orcid": "0000-0003-2408-6606"
#       },
#       {
#         "openalex": "A2013406946",
#         "name": "Branislava Gemovic",
#         "countries": [
#           "Serbia"
#         ],
#         "orcid": "0000-0001-6899-3043"
#       },
#       {
#         "openalex": "A1984769747",
#         "name": "Vladimir Perovic",
#         "countries": [
#           "Serbia"
#         ],
#         "orcid": "0000-0002-3700-6452"
#       },
#       {
#         "openalex": "A2129137781",
#         "name": "Radoslav Davidovic",
#         "countries": [
#           "Serbia"
#         ]
#       },
#       {
#         "openalex": "A2557628388",
#         "name": "Neven Sumonja",
#         "countries": [
#           "Serbia"
#         ]
#       },
#       {
#         "openalex": "A1997854003",
#         "name": "Nevena Veljkovic",
#         "countries": [
#           "Serbia"
#         ],
#         "orcid": "0000-0001-6562-5800"
#       },
#       {
#         "openalex": "A1677516344",
#         "name": "Itamar Borukhov",
#         "countries": [
#           "Israel"
#         ]
#       },
#       {
#         "openalex": "A3001070082",
#         "name": "Po-Han Chi",
#         "countries": [
#           "China"
#         ]
#       },
#       {
#         "openalex": "A2648023924",
#         "name": "Wei-Cheng Tseng",
#         "countries": [
#           "Taiwan, Province of China"
#         ],
#         "orcid": "0000-0003-3528-8633"
#       },
#       {
#         "openalex": "A2244668935",
#         "name": "Michal Linial",
#         "countries": [
#           "Israel"
#         ],
#         "orcid": "0000-0002-9357-4526"
#       },
#       {
#         "openalex": "A2701303639",
#         "name": "Vedrana Vidulin",
#         "countries": [
#           "Slovenia"
#         ]
#       },
#       {
#         "openalex": "A1419022840",
#         "name": "Sašo Džeroski",
#         "countries": [
#           "Slovenia"
#         ],
#         "orcid": "0000-0003-2363-712X"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2596417560",
#     "title": "RNAcentral: a comprehensive database of non-coding RNA sequences",
#     "authors": [
#       {
#         "openalex": "A2776395672",
#         "name": "Magdalena A. Machnicka",
#         "countries": [
#           "Poland"
#         ],
#         "orcid": "0000-0002-2257-2961"
#       },
#       {
#         "openalex": "A94095279",
#         "name": "Janusz M. Bujnicki",
#         "countries": [
#           "Poland"
#         ],
#         "orcid": "0000-0002-6633-165X"
#       },
#       {
#         "openalex": "A2163830880",
#         "name": "Maki Yoshihama",
#         "countries": [
#           "Japan"
#         ]
#       },
#       {
#         "openalex": "A2081433423",
#         "name": "Naoya Kenmochi",
#         "countries": [
#           "Japan"
#         ]
#       },
#       {
#         "openalex": "A2984374445",
#         "name": "Maciej Pawel Szymanski",
#         "countries": [
#           "Poland"
#         ]
#       },
#       {
#         "openalex": "A741715627",
#         "name": "Wojciech M. Karlowski",
#         "countries": [
#           "Poland"
#         ],
#         "orcid": "0000-0002-8086-5404"
#       },
#       {
#         "openalex": "A2493462245",
#         "name": "Yi Zhao",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0003-0892-3988"
#       },
#       {
#         "openalex": "A2096338958",
#         "name": "Di Wu",
#         "countries": [
#           "China"
#         ],
#         "orcid": "0000-0001-6093-0654"
#       },
#       {
#         "openalex": "A1968124348",
#         "name": "Maria D. Paraskevopoulou",
#         "countries": [
#           "Greece"
#         ],
#         "orcid": "0000-0001-8527-5537"
#       },
#       {
#         "openalex": "A2422337378",
#         "name": "Ioannis S. Vlachos",
#         "countries": [
#           "Greece"
#         ],
#         "orcid": "0000-0002-8849-808X"
#       },
#       {
#         "openalex": "A1984268895",
#         "name": "Artemis G. Hatzigeorgiou",
#         "countries": [
#           "Greece"
#         ],
#         "orcid": "0000-0003-1414-5668"
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2558833723",
#     "title": "Manually Curated Database of Rice Proteins (MCDRP), a database of digitized experimental data on rice",
#     "authors": [
#       {
#         "openalex": "A2051056115",
#         "name": "Saurabh Raghuvanshi",
#         "countries": [
#           "India"
#         ],
#         "orcid": "0000-0002-8349-4290"
#       },
#       {
#         "openalex": "A2519282102",
#         "name": "Pratibha Gour",
#         "countries": [
#           "India"
#         ]
#       },
#       {
#         "openalex": "A2100195938",
#         "name": "Shaji Joseph",
#         "countries": [
#           "India"
#         ]
#       }
#     ]
#   },
#   {
#     "id": "https://openalex.org/W2121237412",
#     "title": "Towards BioDBcore: a community-defined information specification for biological databases",
#     "authors": [
#       {
#         "openalex": "A2419836275",
#         "name": "Pascale Gaudet",
#         "countries": [
#           "Philippines"
#         ],
#         "orcid": "0000-0003-1813-6857"
#       },
#       {
#         "openalex": "A3022459435",
#         "name": "Tadashi Gojobori",
#         "countries": [
#           "Japan"
#         ]
#       },
#       {
#         "openalex": "A2042661305",
#         "name": "Tadashi Imanishi",
#         "countries": [
#           "Japan"
#         ],
#         "orcid": "0000-0002-1182-9127"
#       },
#       {
#         "openalex": "A2116731834",
#         "name": "Shoba Ranganathan",
#         "countries": [
#           "Singapore"
#         ],
#         "orcid": "0000-0002-8290-813X"
#       },
#       {
#         "openalex": "A2170850377",
#         "name": "Tin Wee Tan",
#         "countries": [
#           "Singapore"
#         ]
#       },
#       {
#         "openalex": "A1982445405",
#         "name": "Chisato Yamasaki",
#         "countries": [
#           "Japan"
#         ]
#       }
#     ]
#   }
# ]

# %%
w
# Out:
# [{'id': 'https://openalex.org/W2168644196',
#   'doi': 'https://doi.org/10.1093/database/bau070',
#   'title': 'Text-mining-assisted biocuration workflows in Argo',
#   'display_name': 'Text-mining-assisted biocuration workflows in Argo',
#   'relevance_score': 433.71744,
#   'publication_year': 2014,
#   'publication_date': '2014-01-01',
#   'ids': {'openalex': 'https://openalex.org/W2168644196',
#    'doi': 'https://doi.org/10.1093/database/bau070',
#    'mag': '2168644196',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/25037308',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4103424'},
#   'host_venue': {'id': 'https://openalex.org/V4210201630',
#    'issn_l': '1758-0463',
#    'issn': ['1758-0463'],
#    'display_name': 'Database',
#    'publisher': 'University of Oxford',
#    'type': 'journal',
#    'url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/bau070/17472907/bau070.pdf',
#    'is_oa': True,
#    'version': 'publishedVersion',
#    'license': 'cc-by'},
#   'type': 'journal-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'gold',
#    'oa_url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/bau070/17472907/bau070.pdf'},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A2158507047',
#      'display_name': 'Rafal Rak',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I87074743',
#       'display_name': 'University of the Philippines Diliman',
#       'ror': 'https://ror.org/03tbh6y23',
#       'country_code': 'PH',
#       'type': 'education'}],
#     'raw_affiliation_string': 'National Centre for Text Mining, School of Computer Science, University of Manchester, UK and Department of Computer Science, University of the Philippines Diliman, Philippines.'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A1087528918',
#      'display_name': 'Riza Theresa Batista-Navarro',
#      'orcid': 'https://orcid.org/0000-0001-6693-7531'},
#     'institutions': [{'id': 'https://openalex.org/I28407311',
#       'display_name': 'University of Manchester',
#       'ror': 'https://ror.org/027m9bs27',
#       'country_code': 'GB',
#       'type': 'education'}],
#     'raw_affiliation_string': ''},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2160147828',
#      'display_name': 'Andrew F. Rowley',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I87074743',
#       'display_name': 'University of the Philippines Diliman',
#       'ror': 'https://ror.org/03tbh6y23',
#       'country_code': 'PH',
#       'type': 'education'}],
#     'raw_affiliation_string': 'National Centre for Text Mining, School of Computer Science, University of Manchester, UK and Department of Computer Science, University of the Philippines Diliman, Philippines.'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2130666468',
#      'display_name': 'Jacob Carter',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I87074743',
#       'display_name': 'University of the Philippines Diliman',
#       'ror': 'https://ror.org/03tbh6y23',
#       'country_code': 'PH',
#       'type': 'education'}],
#     'raw_affiliation_string': 'National Centre for Text Mining, School of Computer Science, University of Manchester, UK and Department of Computer Science, University of the Philippines Diliman, Philippines.'},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A2141504082',
#      'display_name': 'Sophia Ananiadou',
#      'orcid': 'https://orcid.org/0000-0002-4097-9191'},
#     'institutions': [{'id': 'https://openalex.org/I87074743',
#       'display_name': 'University of the Philippines Diliman',
#       'ror': 'https://ror.org/03tbh6y23',
#       'country_code': 'PH',
#       'type': 'education'}],
#     'raw_affiliation_string': 'National Centre for Text Mining, School of Computer Science, University of Manchester, UK and Department of Computer Science, University of the Philippines Diliman, Philippines.'}],
#   'cited_by_count': 20,
#   'biblio': {'volume': None,
#    'issue': None,
#    'first_page': None,
#    'last_page': None},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C2779145975',
#     'wikidata': 'https://www.wikidata.org/wiki/Q347690',
#     'display_name': 'Workbench',
#     'level': 3,
#     'score': '0.7908777'},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': '0.7849556'},
#    {'id': 'https://openalex.org/C51614570',
#     'wikidata': 'https://www.wikidata.org/wiki/Q647931',
#     'display_name': 'Argo',
#     'level': 2,
#     'score': '0.7227073'},
#    {'id': 'https://openalex.org/C177212765',
#     'wikidata': 'https://www.wikidata.org/wiki/Q627335',
#     'display_name': 'Workflow',
#     'level': 2,
#     'score': '0.6879818'},
#    {'id': 'https://openalex.org/C136764020',
#     'wikidata': 'https://www.wikidata.org/wiki/Q466',
#     'display_name': 'World Wide Web',
#     'level': 1,
#     'score': '0.5828688'},
#    {'id': 'https://openalex.org/C37789001',
#     'wikidata': 'https://www.wikidata.org/wiki/Q782543',
#     'display_name': 'Graphical user interface',
#     'level': 2,
#     'score': '0.5268751'},
#    {'id': 'https://openalex.org/C2776321320',
#     'wikidata': 'https://www.wikidata.org/wiki/Q857525',
#     'display_name': 'Annotation',
#     'level': 2,
#     'score': '0.51218414'},
#    {'id': 'https://openalex.org/C79158427',
#     'wikidata': 'https://www.wikidata.org/wiki/Q485396',
#     'display_name': 'Analytics',
#     'level': 2,
#     'score': '0.49958897'},
#    {'id': 'https://openalex.org/C89505385',
#     'wikidata': 'https://www.wikidata.org/wiki/Q47146',
#     'display_name': 'User interface',
#     'level': 2,
#     'score': '0.47464022'},
#    {'id': 'https://openalex.org/C2780451532',
#     'wikidata': 'https://www.wikidata.org/wiki/Q759676',
#     'display_name': 'Task (project management)',
#     'level': 2,
#     'score': '0.4698559'},
#    {'id': 'https://openalex.org/C113843644',
#     'wikidata': 'https://www.wikidata.org/wiki/Q901882',
#     'display_name': 'Interface (matter)',
#     'level': 4,
#     'score': '0.44372353'},
#    {'id': 'https://openalex.org/C23123220',
#     'wikidata': 'https://www.wikidata.org/wiki/Q816826',
#     'display_name': 'Information retrieval',
#     'level': 1,
#     'score': '0.4222238'},
#    {'id': 'https://openalex.org/C20136886',
#     'wikidata': 'https://www.wikidata.org/wiki/Q749647',
#     'display_name': 'Interoperability',
#     'level': 2,
#     'score': '0.42097405'},
#    {'id': 'https://openalex.org/C91632574',
#     'wikidata': 'https://www.wikidata.org/wiki/Q15088675',
#     'display_name': 'Data curation',
#     'level': 2,
#     'score': '0.41647214'},
#    {'id': 'https://openalex.org/C2522767166',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2374463',
#     'display_name': 'Data science',
#     'level': 1,
#     'score': '0.36297518'},
#    {'id': 'https://openalex.org/C36464697',
#     'wikidata': 'https://www.wikidata.org/wiki/Q451553',
#     'display_name': 'Visualization',
#     'level': 2,
#     'score': '0.28141683'},
#    {'id': 'https://openalex.org/C77088390',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8513',
#     'display_name': 'Database',
#     'level': 1,
#     'score': '0.2146641'},
#    {'id': 'https://openalex.org/C124101348',
#     'wikidata': 'https://www.wikidata.org/wiki/Q172491',
#     'display_name': 'Data mining',
#     'level': 1,
#     'score': '0.1398238'},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': '0.13198125'},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': '0.09029412'},
#    {'id': 'https://openalex.org/C111368507',
#     'wikidata': 'https://www.wikidata.org/wiki/Q43518',
#     'display_name': 'Oceanography',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C201995342',
#     'wikidata': 'https://www.wikidata.org/wiki/Q682496',
#     'display_name': 'Systems engineering',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C157915830',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2928001',
#     'display_name': 'Bubble',
#     'level': 2,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C129307140',
#     'wikidata': 'https://www.wikidata.org/wiki/Q6795880',
#     'display_name': 'Maximum bubble pressure method',
#     'level': 3,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C173608175',
#     'wikidata': 'https://www.wikidata.org/wiki/Q232661',
#     'display_name': 'Parallel computing',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C199360897',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#     'display_name': 'Programming language',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C127313418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#     'display_name': 'Geology',
#     'level': 0,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C111919701',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#     'display_name': 'Operating system',
#     'level': 1,
#     'score': '0.0'}],
#   'mesh': [{'descriptor_ui': 'D066289',
#     'descriptor_name': 'Data Curation',
#     'qualifier_ui': 'Q000379',
#     'qualifier_name': 'methods',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D057225',
#     'descriptor_name': 'Data Mining',
#     'qualifier_ui': 'Q000379',
#     'qualifier_name': 'methods',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D020407',
#     'descriptor_name': 'Internet',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': True},
#    {'descriptor_ui': 'D012984',
#     'descriptor_name': 'Software',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': True},
#    {'descriptor_ui': 'D066289',
#     'descriptor_name': 'Data Curation',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D057225',
#     'descriptor_name': 'Data Mining',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D006801',
#     'descriptor_name': 'Humans',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D058977',
#     'descriptor_name': 'Molecular Sequence Annotation',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D013997',
#     'descriptor_name': 'Time Factors',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D014584',
#     'descriptor_name': 'User-Computer Interface',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False}],
#   'alternate_host_venues': [{'id': 'https://openalex.org/V4210201630',
#     'display_name': 'Database',
#     'type': 'journal',
#     'url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/bau070/17472907/bau070.pdf',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by'},
#    {'id': 'https://openalex.org/V4306400806',
#     'display_name': 'PubMed Central - Europe PMC',
#     'type': 'repository',
#     'url': 'https://europepmc.org/articles/pmc4103424?pdf=render',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by'},
#    {'id': 'https://openalex.org/V2764455111',
#     'display_name': 'PubMed Central',
#     'type': 'repository',
#     'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4103424',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': None}],
#   'referenced_works': ['https://openalex.org/W122891110',
#    'https://openalex.org/W1965893653',
#    'https://openalex.org/W1977289091',
#    'https://openalex.org/W1989263028',
#    'https://openalex.org/W2009033874',
#    'https://openalex.org/W2028133290',
#    'https://openalex.org/W2032729847',
#    'https://openalex.org/W2034190452',
#    'https://openalex.org/W2053673723',
#    'https://openalex.org/W2069024774',
#    'https://openalex.org/W2089988218',
#    'https://openalex.org/W2094726706',
#    'https://openalex.org/W2096797897',
#    'https://openalex.org/W2097678794',
#    'https://openalex.org/W2098166827',
#    'https://openalex.org/W2099701465',
#    'https://openalex.org/W2102160502',
#    'https://openalex.org/W2108723491',
#    'https://openalex.org/W2110408238',
#    'https://openalex.org/W2120754707',
#    'https://openalex.org/W2127239015',
#    'https://openalex.org/W2129592938',
#    'https://openalex.org/W2131848047',
#    'https://openalex.org/W2135118172',
#    'https://openalex.org/W2139259976',
#    'https://openalex.org/W2140611297',
#    'https://openalex.org/W2146486983',
#    'https://openalex.org/W4237293127',
#    'https://openalex.org/W4247554111',
#    'https://openalex.org/W4255855797'],
#   'related_works': ['https://openalex.org/W1964670939',
#    'https://openalex.org/W1971898004',
#    'https://openalex.org/W2002848266',
#    'https://openalex.org/W2049064648',
#    'https://openalex.org/W2056701505',
#    'https://openalex.org/W2094726706',
#    'https://openalex.org/W2099701465',
#    'https://openalex.org/W2104148262',
#    'https://openalex.org/W2104655105',
#    'https://openalex.org/W2141593186',
#    'https://openalex.org/W2147641929',
#    'https://openalex.org/W2169425537',
#    'https://openalex.org/W2402320467',
#    'https://openalex.org/W2557315899',
#    'https://openalex.org/W2586226478',
#    'https://openalex.org/W2789889445',
#    'https://openalex.org/W2956084751',
#    'https://openalex.org/W3027933721',
#    'https://openalex.org/W3043657477',
#    'https://openalex.org/W3089942063'],
#   'ngrams_url': 'https://api.openalex.org/works/W2168644196/ngrams',
#   'abstract_inverted_index': {'Biocuration': [0],
#    'activities': [1],
#    'have': [2, 32, 51, 216, 255, 282],
#    'been': [3, 29, 52, 284],
#    'broadly': [4],
#    'categorized': [5],
#    'into': [6, 54],
#    'the': [7,
#     12,
#     24,
#     38,
#     44,
#     62,
#     73,
#     82,
#     111,
#     118,
#     148,
#     177,
#     188,
#     198,
#     217,
#     232,
#     235,
#     239,
#     241,
#     246,
#     251,
#     257,
#     264],
#    'selection': [8],
#    'of': [9,
#     14,
#     17,
#     21,
#     40,
#     64,
#     75,
#     84,
#     117,
#     151,
#     179,
#     190,
#     224,
#     226,
#     234,
#     259,
#     277,
#     280],
#    'relevant': [10],
#    'documents,': [11],
#    'annotation': [13, 108],
#    'biological': [15],
#    'concepts': [16],
#    'interest': [18],
#    'and': [19, 47, 145, 157, 173, 274],
#    'identification': [20],
#    'interactions': [22],
#    'between': [23],
#    'concepts.': [25],
#    'Text': [26],
#    'mining': [27],
#    'has': [28],
#    'shown': [30],
#    'to': [31, 35, 57, 87, 100, 124, 205, 215, 270],
#    'a': [33, 66, 76],
#    'potential': [34],
#    'significantly': [36],
#    'reduce': [37],
#    'effort': [39],
#    'biocurators': [41],
#    'in': [42, 128, 197, 222, 263],
#    'all': [43],
#    'three': [45],
#    'activities,': [46, 194],
#    'various': [48],
#    'semi-automatic': [49],
#    'methodologies': [50],
#    'integrated': [53],
#    'curation': [55, 193],
#    'pipelines': [56],
#    'support': [58, 160],
#    'them.': [59],
#    'We': [60],
#    'investigate': [61],
#    'suitability': [63, 189],
#    'Argo,': [65],
#    'workbench': [67, 236],
#    'for': [68, 81, 192],
#    'building': [69],
#    'text-mining': [70],
#    'solutions': [71],
#    'with': [72, 181],
#    'use': [74],
#    'rich': [77],
#    'graphical': [78],
#    'user': [79],
#    'interface,': [80],
#    'process': [83],
#    'biocuration.': [85],
#    'Central': [86],
#    'Argo': [88, 180, 191, 213],
#    'are': [89],
#    'customizable': [90],
#    'workflows': [91],
#    'that': [92, 159],
#    'users': [93, 123],
#    'compose': [94],
#    'by': [95, 138],
#    'arranging': [96],
#    'available': [97],
#    'elementary': [98],
#    'analytics': [99],
#    'form': [101],
#    'task-specific': [102],
#    'processing': [103, 140],
#    'units.': [104],
#    'A': [105],
#    'built-in': [106],
#    'manual': [107],
#    'editor': [109],
#    'is': [110],
#    'single': [112],
#    'most': [113],
#    'used': [114],
#    'biocuration': [115, 211, 228],
#    'tool': [116],
#    'workbench,': [119],
#    'as': [120, 130, 132, 162, 164, 170],
#    'it': [121],
#    'allows': [122],
#    'create': [125],
#    'annotations': [126, 136],
#    'directly': [127],
#    'text,': [129],
#    'well': [131, 163],
#    'modify': [133],
#    'or': [134, 184],
#    'delete': [135],
#    'created': [137],
#    'automatic': [139],
#    'components.': [141],
#    'Apart': [142],
#    'from': [143],
#    'syntactic': [144],
#    'semantic': [146],
#    'analytics,': [147],
#    'ever-growing': [149],
#    'library': [150],
#    'components': [152],
#    'includes': [153],
#    'several': [154],
#    'data': [155, 166],
#    'readers': [156],
#    'consumers': [158],
#    'well-established': [161],
#    'emerging': [165],
#    'interchange': [167],
#    'formats': [168],
#    'such': [169],
#    'XMI,': [171],
#    'RDF': [172],
#    'BioC,': [174],
#    'which': [175, 253, 281],
#    'facilitate': [176],
#    'interoperability': [178],
#    'other': [182, 220],
#    'platforms': [183],
#    'resources.': [185],
#    'To': [186],
#    'validate': [187],
#    'we': [195],
#    'participated': [196],
#    'BioCreative': [199],
#    'IV': [200],
#    'challenge': [201, 265],
#    'whose': [202],
#    'purpose': [203],
#    'was': [204],
#    'evaluate': [206],
#    'Web-based': [207],
#    'systems': [208, 221],
#    'addressing': [209],
#    'user-defined': [210],
#    'tasks.': [212, 229],
#    'proved': [214],
#    'edge': [218],
#    'over': [219],
#    'terms': [223],
#    'flexibility': [225],
#    'defining': [227],
#    'As': [230],
#    'expected,': [231],
#    'versatility': [233],
#    'inevitably': [237],
#    'lengthened': [238],
#    'time': [240],
#    'curators': [242],
#    'spent': [243],
#    'on': [244, 250],
#    'learning': [245],
#    'system': [247],
#    'before': [248],
#    'taking': [249],
#    'task,': [252],
#    'may': [254],
#    'affected': [256],
#    'usability': [258],
#    'Argo.': [260],
#    'The': [261],
#    'participation': [262],
#    'gave': [266],
#    'us': [267],
#    'an': [268],
#    'opportunity': [269],
#    'gather': [271],
#    'valuable': [272],
#    'feedback': [273],
#    'identify': [275],
#    'areas': [276],
#    'improvement,': [278],
#    'some': [279],
#    'already': [283],
#    'introduced.': [285],
#    'Database': [286],
#    'URL:': [287],
#    'http://argo.nactem.ac.uk.': [288]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2168644196',
#   'counts_by_year': [{'year': 2022, 'cited_by_count': 1},
#    {'year': 2020, 'cited_by_count': 1},
#    {'year': 2019, 'cited_by_count': 1},
#    {'year': 2018, 'cited_by_count': 3},
#    {'year': 2017, 'cited_by_count': 5},
#    {'year': 2016, 'cited_by_count': 5},
#    {'year': 2015, 'cited_by_count': 2},
#    {'year': 2014, 'cited_by_count': 2}],
#   'updated_date': '2023-01-20T00:36:53.981297',
#   'created_date': '2016-06-24'},
#  {'id': 'https://openalex.org/W1980075500',
#   'doi': 'https://doi.org/10.1016/j.gpb.2014.07.001',
#   'title': 'Bringing Biocuration to China',
#   'display_name': 'Bringing Biocuration to China',
#   'relevance_score': 317.9799,
#   'publication_year': 2014,
#   'publication_date': '2014-08-01',
#   'ids': {'openalex': 'https://openalex.org/W1980075500',
#    'doi': 'https://doi.org/10.1016/j.gpb.2014.07.001',
#    'mag': '1980075500',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/25042682',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4411340'},
#   'host_venue': {'id': 'https://openalex.org/V155547894',
#    'issn_l': '1672-0229',
#    'issn': ['2210-3244', '1672-0229'],
#    'display_name': 'Genomics, Proteomics & Bioinformatics',
#    'publisher': 'Elsevier BV',
#    'type': 'journal',
#    'url': 'https://doi.org/10.1016/j.gpb.2014.07.001',
#    'is_oa': True,
#    'version': 'publishedVersion',
#    'license': 'cc-by-nc-nd'},
#   'type': 'journal-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'gold',
#    'oa_url': 'https://doi.org/10.1016/j.gpb.2014.07.001'},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A2170102332',
#      'display_name': 'Zhang Zhang',
#      'orcid': 'https://orcid.org/0000-0001-6603-5060'},
#     'institutions': [{'id': 'https://openalex.org/I2801577699',
#       'display_name': 'Beijing Institute of Genomics',
#       'ror': 'https://ror.org/049gn7z52',
#       'country_code': 'CN',
#       'type': 'facility'}],
#     'raw_affiliation_string': 'CAS Key Laboratory of Genome Sciences and Information, Beijing Institute of Genomics, Chinese Academy of Sciences , Beijing, 100101, China.'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2965461387',
#      'display_name': 'Weimin Zhu',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I200296433',
#       'display_name': 'Chinese Academy of Medical Sciences & Peking Union Medical College',
#       'ror': 'https://ror.org/02drdmm93',
#       'country_code': 'CN',
#       'type': 'education'}],
#     'raw_affiliation_string': 'Institute of Basic Medical Sciences, Chinese Academy of Medical Sciences, Beijing 100730, China; Taicang Institute of Life Sciences Information, Taicang 215400, China.'},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A2012658727',
#      'display_name': 'Jingchu Luo',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I20231570',
#       'display_name': 'Peking University',
#       'ror': 'https://ror.org/02v51f717',
#       'country_code': 'CN',
#       'type': 'education'}],
#     'raw_affiliation_string': 'College of Life Sciences and Center for Bioinformatics, Peking University, Beijing 100871, China.'}],
#   'cited_by_count': 9,
#   'biblio': {'volume': '12',
#    'issue': '4',
#    'first_page': '153',
#    'last_page': '155'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C188087704',
#     'wikidata': 'https://www.wikidata.org/wiki/Q369577',
#     'display_name': 'Standardization',
#     'level': 2,
#     'score': '0.67556167'},
#    {'id': 'https://openalex.org/C20136886',
#     'wikidata': 'https://www.wikidata.org/wiki/Q749647',
#     'display_name': 'Interoperability',
#     'level': 2,
#     'score': '0.58594775'},
#    {'id': 'https://openalex.org/C91632574',
#     'wikidata': 'https://www.wikidata.org/wiki/Q15088675',
#     'display_name': 'Data curation',
#     'level': 2,
#     'score': '0.539328'},
#    {'id': 'https://openalex.org/C191935318',
#     'wikidata': 'https://www.wikidata.org/wiki/Q148',
#     'display_name': 'China',
#     'level': 2,
#     'score': '0.520701'},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': '0.47926852'},
#    {'id': 'https://openalex.org/C136764020',
#     'wikidata': 'https://www.wikidata.org/wiki/Q466',
#     'display_name': 'World Wide Web',
#     'level': 1,
#     'score': '0.47074136'},
#    {'id': 'https://openalex.org/C2522767166',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2374463',
#     'display_name': 'Data science',
#     'level': 1,
#     'score': '0.42438334'},
#    {'id': 'https://openalex.org/C161191863',
#     'wikidata': 'https://www.wikidata.org/wiki/Q199655',
#     'display_name': 'Library science',
#     'level': 1,
#     'score': '0.32848483'},
#    {'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': '0.19587767'},
#    {'id': 'https://openalex.org/C199539241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#     'display_name': 'Law',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C111919701',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#     'display_name': 'Operating system',
#     'level': 1,
#     'score': '0.0'}],
#   'mesh': [{'descriptor_ui': 'D035843',
#     'descriptor_name': 'Biomedical Research',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': True},
#    {'descriptor_ui': 'D003628',
#     'descriptor_name': 'Database Management Systems',
#     'qualifier_ui': 'Q000458',
#     'qualifier_name': 'organization & administration',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D030541',
#     'descriptor_name': 'Databases, Genetic',
#     'qualifier_ui': 'Q000639',
#     'qualifier_name': 'trends',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D030562',
#     'descriptor_name': 'Databases, Protein',
#     'qualifier_ui': 'Q000639',
#     'qualifier_name': 'trends',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D002681',
#     'descriptor_name': 'China',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D003628',
#     'descriptor_name': 'Database Management Systems',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D003628',
#     'descriptor_name': 'Database Management Systems',
#     'qualifier_ui': 'Q000639',
#     'qualifier_name': 'trends',
#     'is_major_topic': False},
#    {'descriptor_ui': 'D030541',
#     'descriptor_name': 'Databases, Genetic',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D030562',
#     'descriptor_name': 'Databases, Protein',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D006801',
#     'descriptor_name': 'Humans',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D000078329',
#     'descriptor_name': 'Workforce',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False}],
#   'alternate_host_venues': [{'id': 'https://openalex.org/V155547894',
#     'display_name': 'Genomics, Proteomics & Bioinformatics',
#     'type': 'journal',
#     'url': 'https://doi.org/10.1016/j.gpb.2014.07.001',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by-nc-nd'},
#    {'id': 'https://openalex.org/V4306400806',
#     'display_name': 'PubMed Central - Europe PMC',
#     'type': 'repository',
#     'url': 'https://europepmc.org/articles/pmc4411340?pdf=render',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by-nc-nd'},
#    {'id': 'https://openalex.org/V2764455111',
#     'display_name': 'PubMed Central',
#     'type': 'repository',
#     'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4411340',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': None}],
#   'referenced_works': ['https://openalex.org/W2073645019',
#    'https://openalex.org/W2091940856',
#    'https://openalex.org/W2099230441',
#    'https://openalex.org/W2118062583',
#    'https://openalex.org/W2119752985',
#    'https://openalex.org/W2147719979',
#    'https://openalex.org/W2170985734'],
#   'related_works': ['https://openalex.org/W1894535452',
#    'https://openalex.org/W1915711084',
#    'https://openalex.org/W2040730310',
#    'https://openalex.org/W2119748718',
#    'https://openalex.org/W2416633524',
#    'https://openalex.org/W2984979053',
#    'https://openalex.org/W2999715761',
#    'https://openalex.org/W3010494567',
#    'https://openalex.org/W3122047183',
#    'https://openalex.org/W3199351879'],
#   'ngrams_url': 'https://api.openalex.org/works/W1980075500/ngrams',
#   'abstract_inverted_index': {'Biocuration': [0, 96],
#    'involves': [1],
#    'adding': [2],
#    'value': [3],
#    'to': [4, 52, 98, 109],
#    'biomedical': [5, 33, 55, 90],
#    'data': [6, 20, 24, 34, 45, 56, 91],
#    'by': [7, 89],
#    'the': [8, 53, 70, 107, 111, 117],
#    'processes': [9],
#    'of': [10, 116, 120],
#    'standardization,': [11],
#    'quality': [12],
#    'control': [13],
#    'and': [14, 26, 28],
#    'information': [15],
#    'transferring': [16],
#    '(also': [17],
#    'known': [18],
#    'as': [19, 79],
#    'annotation).': [21],
#    'It': [22],
#    'enhances': [23],
#    'interoperability': [25],
#    'consistency,': [27],
#    'is': [29, 40, 48],
#    'critical': [30],
#    'in': [31, 67, 101, 114, 122, 129],
#    'translating': [32],
#    'into': [35],
#    'scientific': [36, 44, 123],
#    'discovery.': [37, 124],
#    'Although': [38],
#    'China': [39, 102, 115],
#    'becoming': [41],
#    'a': [42],
#    'leading': [43],
#    'producer,': [46],
#    'biocuration': [47, 121],
#    'still': [49],
#    'very': [50],
#    'new': [51],
#    'Chinese': [54, 68, 77],
#    'community.': [57, 92],
#    'In': [58],
#    'fact,': [59],
#    'there': [60],
#    'currently': [61],
#    'lacks': [62],
#    'an': [63],
#    'equivalent': [64],
#    'acknowledged': [65],
#    'word': [66, 71],
#    'for': [69],
#    '"curation".': [72],
#    'Here': [73],
#    'we': [74],
#    'propose': [75],
#    'its': [76, 85, 130],
#    'translation': [78],
#    '(Pinyin)': [80],
#    '"shěn': [81],
#    'biān",': [82],
#    'based': [83],
#    'on': [84],
#    'implied': [86],
#    'meanings': [87],
#    'taken': [88],
#    'The': [93],
#    '8th': [94],
#    'International': [95],
#    'Conference': [97],
#    'be': [99],
#    'held': [100],
#    '(http://biocuration2015.tilsi.org)': [103],
#    'next': [104],
#    'year': [105],
#    'bears': [106],
#    'potential': [108],
#    'raise': [110],
#    'general': [112],
#    'awareness': [113],
#    'significant': [118],
#    'role': [119],
#    'However,': [125],
#    'challenges': [126],
#    'are': [127],
#    'ahead': [128],
#    'implementation.': [131]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W1980075500',
#   'counts_by_year': [{'year': 2022, 'cited_by_count': 1},
#    {'year': 2020, 'cited_by_count': 1},
#    {'year': 2018, 'cited_by_count': 1},
#    {'year': 2017, 'cited_by_count': 2},
#    {'year': 2016, 'cited_by_count': 2},
#    {'year': 2015, 'cited_by_count': 2}],
#   'updated_date': '2023-01-24T18:28:52.164607',
#   'created_date': '2016-06-24'},
#  {'id': 'https://openalex.org/W2097456924',
#   'doi': 'https://doi.org/10.1093/database/bas038',
#   'title': 'Developing a biocuration workflow for AgBase, a non-model organism database',
#   'display_name': 'Developing a biocuration workflow for AgBase, a non-model organism database',
#   'relevance_score': 201.86313,
#   'publication_year': 2012,
#   'publication_date': '2012-01-01',
#   'ids': {'openalex': 'https://openalex.org/W2097456924',
#    'doi': 'https://doi.org/10.1093/database/bas038',
#    'mag': '2097456924',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/23160411',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/3500517'},
#   'host_venue': {'id': 'https://openalex.org/V4210201630',
#    'issn_l': '1758-0463',
#    'issn': ['1758-0463'],
#    'display_name': 'Database',
#    'publisher': 'University of Oxford',
#    'type': 'journal',
#    'url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/bas038/1203012/bas038.pdf',
#    'is_oa': True,
#    'version': 'publishedVersion',
#    'license': 'cc-by'},
#   'type': 'journal-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'gold',
#    'oa_url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/bas038/1203012/bas038.pdf'},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A2057629642',
#      'display_name': 'Lakshmi Pillai',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I99041443',
#       'display_name': 'Mississippi State University',
#       'ror': 'https://ror.org/0432jq872',
#       'country_code': 'US',
#       'type': 'education'}],
#     'raw_affiliation_string': 'Department of Basic Sciences, College of Veterinary Medicine, Mississippi State University, MS 39762, USA'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A1796085180',
#      'display_name': 'Philippe Chouvarine',
#      'orcid': 'https://orcid.org/0000-0003-0563-315X'},
#     'institutions': [{'id': 'https://openalex.org/I3130035786',
#       'display_name': 'University Ucinf',
#       'ror': 'https://ror.org/02cs9pv18',
#       'country_code': 'CL',
#       'type': 'education'}],
#     'raw_affiliation_string': ''},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2075257882',
#      'display_name': 'Catalina O. Tudor',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I3130035786',
#       'display_name': 'University Ucinf',
#       'ror': 'https://ror.org/02cs9pv18',
#       'country_code': 'CL',
#       'type': 'education'}],
#     'raw_affiliation_string': ''},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2121571163',
#      'display_name': 'Carl Schmidt',
#      'orcid': 'https://orcid.org/0000-0001-6126-8789'},
#     'institutions': [{'id': 'https://openalex.org/I3130035786',
#       'display_name': 'University Ucinf',
#       'ror': 'https://ror.org/02cs9pv18',
#       'country_code': 'CL',
#       'type': 'education'}],
#     'raw_affiliation_string': ''},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2700688118',
#      'display_name': 'K. Vijay-Shanker',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I3130035786',
#       'display_name': 'University Ucinf',
#       'ror': 'https://ror.org/02cs9pv18',
#       'country_code': 'CL',
#       'type': 'education'}],
#     'raw_affiliation_string': ''},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A2036408155',
#      'display_name': 'Fiona M. McCarthy',
#      'orcid': 'https://orcid.org/0000-0003-2175-5464'},
#     'institutions': [{'id': 'https://openalex.org/I3130035786',
#       'display_name': 'University Ucinf',
#       'ror': 'https://ror.org/02cs9pv18',
#       'country_code': 'CL',
#       'type': 'education'}],
#     'raw_affiliation_string': ''}],
#   'cited_by_count': 7,
#   'biblio': {'volume': '2012',
#    'issue': '0',
#    'first_page': 'bas038',
#    'last_page': 'bas038'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C2776321320',
#     'wikidata': 'https://www.wikidata.org/wiki/Q857525',
#     'display_name': 'Annotation',
#     'level': 2,
#     'score': '0.75967664'},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': '0.6667259'},
#    {'id': 'https://openalex.org/C62177273',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5531556',
#     'display_name': 'Gene nomenclature',
#     'level': 4,
#     'score': '0.6592443'},
#    {'id': 'https://openalex.org/C113843644',
#     'wikidata': 'https://www.wikidata.org/wiki/Q901882',
#     'display_name': 'Interface (matter)',
#     'level': 4,
#     'score': '0.61451936'},
#    {'id': 'https://openalex.org/C23123220',
#     'wikidata': 'https://www.wikidata.org/wiki/Q816826',
#     'display_name': 'Information retrieval',
#     'level': 1,
#     'score': '0.56007594'},
#    {'id': 'https://openalex.org/C177212765',
#     'wikidata': 'https://www.wikidata.org/wiki/Q627335',
#     'display_name': 'Workflow',
#     'level': 2,
#     'score': '0.49427915'},
#    {'id': 'https://openalex.org/C2908923196',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5205742',
#     'display_name': 'Gene Annotation',
#     'level': 4,
#     'score': '0.42820257'},
#    {'id': 'https://openalex.org/C91632574',
#     'wikidata': 'https://www.wikidata.org/wiki/Q15088675',
#     'display_name': 'Data curation',
#     'level': 2,
#     'score': '0.42463356'},
#    {'id': 'https://openalex.org/C104317684',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7187',
#     'display_name': 'Gene',
#     'level': 2,
#     'score': '0.42187512'},
#    {'id': 'https://openalex.org/C77088390',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8513',
#     'display_name': 'Database',
#     'level': 1,
#     'score': '0.37892112'},
#    {'id': 'https://openalex.org/C136764020',
#     'wikidata': 'https://www.wikidata.org/wiki/Q466',
#     'display_name': 'World Wide Web',
#     'level': 1,
#     'score': '0.3581996'},
#    {'id': 'https://openalex.org/C70721500',
#     'wikidata': 'https://www.wikidata.org/wiki/Q177005',
#     'display_name': 'Computational biology',
#     'level': 1,
#     'score': '0.33875465'},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': '0.2495144'},
#    {'id': 'https://openalex.org/C141231307',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7020',
#     'display_name': 'Genome',
#     'level': 3,
#     'score': '0.24596515'},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': '0.14880213'},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': '0.14814502'},
#    {'id': 'https://openalex.org/C58642233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8269924',
#     'display_name': 'Taxonomy (biology)',
#     'level': 2,
#     'score': '0.0855068'},
#    {'id': 'https://openalex.org/C59822182',
#     'wikidata': 'https://www.wikidata.org/wiki/Q441',
#     'display_name': 'Botany',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C157915830',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2928001',
#     'display_name': 'Bubble',
#     'level': 2,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C129307140',
#     'wikidata': 'https://www.wikidata.org/wiki/Q6795880',
#     'display_name': 'Maximum bubble pressure method',
#     'level': 3,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C173608175',
#     'wikidata': 'https://www.wikidata.org/wiki/Q232661',
#     'display_name': 'Parallel computing',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C514705636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q863247',
#     'display_name': 'Nomenclature',
#     'level': 3,
#     'score': '0.0'}],
#   'mesh': [{'descriptor_ui': 'D000383',
#     'descriptor_name': 'Agriculture',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': True},
#    {'descriptor_ui': 'D057225',
#     'descriptor_name': 'Data Mining',
#     'qualifier_ui': 'Q000379',
#     'qualifier_name': 'methods',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D030541',
#     'descriptor_name': 'Databases, Genetic',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': True},
#    {'descriptor_ui': 'D057188',
#     'descriptor_name': 'Workflow',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': True},
#    {'descriptor_ui': 'D057225',
#     'descriptor_name': 'Data Mining',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D017343',
#     'descriptor_name': 'Genes, Plant',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D017343',
#     'descriptor_name': 'Genes, Plant',
#     'qualifier_ui': 'Q000235',
#     'qualifier_name': 'genetics',
#     'is_major_topic': False},
#    {'descriptor_ui': 'D058977',
#     'descriptor_name': 'Molecular Sequence Annotation',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D010506',
#     'descriptor_name': 'Periodicals as Topic',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D011786',
#     'descriptor_name': 'Quality Control',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False}],
#   'alternate_host_venues': [{'id': 'https://openalex.org/V4210201630',
#     'display_name': 'Database',
#     'type': 'journal',
#     'url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/bas038/1203012/bas038.pdf',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by'},
#    {'id': 'https://openalex.org/V4306400806',
#     'display_name': 'PubMed Central - Europe PMC',
#     'type': 'repository',
#     'url': 'https://europepmc.org/articles/pmc3500517?pdf=render',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by-nc'},
#    {'id': 'https://openalex.org/V2764455111',
#     'display_name': 'PubMed Central',
#     'type': 'repository',
#     'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3500517',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': None}],
#   'referenced_works': ['https://openalex.org/W2018925823',
#    'https://openalex.org/W2075027317',
#    'https://openalex.org/W2097898123',
#    'https://openalex.org/W2128119041',
#    'https://openalex.org/W2168340032'],
#   'related_works': ['https://openalex.org/W1972257067',
#    'https://openalex.org/W2097456924',
#    'https://openalex.org/W2127546476',
#    'https://openalex.org/W2169425537',
#    'https://openalex.org/W2404565489',
#    'https://openalex.org/W2785632727',
#    'https://openalex.org/W2898598946',
#    'https://openalex.org/W2999699891',
#    'https://openalex.org/W3156936474',
#    'https://openalex.org/W4309908782'],
#   'ngrams_url': 'https://api.openalex.org/works/W2097456924/ngrams',
#   'abstract_inverted_index': {'AgBase': [0, 110, 169, 272],
#    'provides': [1],
#    'annotation': [2, 53, 73, 99, 277, 285],
#    'for': [3, 46, 64, 74, 100, 124, 175],
#    'agricultural': [4, 21, 185, 287],
#    'gene': [5, 34, 57, 62, 70, 101, 126, 195, 208, 238, 288],
#    'products': [6, 63, 102],
#    'using': [7],
#    'the': [8, 56, 68, 105, 141, 207, 263],
#    'Gene': [9],
#    'Ontology': [10],
#    '(GO)': [11],
#    'and': [12, 71, 103, 140, 143, 197, 228],
#    'Plant': [13],
#    'Ontology,': [14],
#    'as': [15, 77, 257],
#    'appropriate.': [16],
#    'Unlike': [17],
#    'model': [18],
#    'organism': [19],
#    'species,': [20],
#    'species': [22, 186],
#    'have': [23, 189, 267],
#    'a': [24, 130, 160, 165, 215, 237],
#    'body': [25],
#    'of': [26, 51, 206, 286],
#    'literature': [27, 45, 174],
#    'that': [28, 60, 134, 221, 235, 266],
#    'does': [29],
#    'not': [30, 188, 223],
#    'just': [31],
#    'focus': [32],
#    'on': [33, 179],
#    'function;': [35],
#    'to': [36, 43, 85, 88, 108, 153, 171, 199, 218, 225, 232, 245, 262, 279],
#    'improve': [37],
#    'efficiency,': [38],
#    'we': [39],
#    'use': [40],
#    'text': [41],
#    'mining': [42],
#    'identify': [44, 173],
#    'curation.': [47],
#    'The': [48, 113, 241, 271],
#    'first': [49],
#    'component': [50],
#    'our': [52, 89, 246, 281],
#    'interface': [54, 59, 91, 107],
#    'is': [55, 104, 129, 230, 243],
#    'prioritization': [58],
#    'ranks': [61],
#    'annotation.': [65, 270],
#    'Biocurators': [66],
#    'select': [67],
#    'top-ranked': [69],
#    'mark': [72],
#    'these': [75],
#    'genes': [76],
#    "'in": [78],
#    "progress'": [79],
#    'or': [80, 164],
#    "'completed';": [81],
#    'links': [82],
#    'enable': [83],
#    'biocurators': [84, 170, 259],
#    'move': [86],
#    'directly': [87],
#    'biocuration': [90],
#    '(BI).': [92],
#    'Our': [93],
#    'BI': [94, 114, 242, 273],
#    'includes': [95],
#    'all': [96, 194],
#    'current': [97],
#    'GO': [98, 154, 161, 181, 269, 295],
#    'main': [106],
#    'add/modify': [109],
#    'curation': [111, 177],
#    'data.': [112],
#    'also': [115, 260, 274],
#    'displays': [116],
#    'Extracting': [117],
#    'Genic': [118],
#    'Information': [119],
#    'from': [120, 283],
#    'Text': [121],
#    '(eGIFT)': [122],
#    'results': [123],
#    'each': [125],
#    'product.': [127],
#    'eGIFT': [128, 192, 213],
#    'web-based,': [131],
#    'text-mining': [132],
#    'tool': [133],
#    'associates': [135],
#    'ranked,': [136],
#    'informative': [137],
#    'terms': [138],
#    '(iTerms)': [139],
#    'articles': [142, 201],
#    'sentences': [144],
#    'containing': [145],
#    'them,': [146],
#    'with': [147, 202],
#    'genes.': [148, 203],
#    'Moreover,': [149],
#    'iTerms': [150],
#    'are': [151, 254],
#    'linked': [152, 244],
#    'terms,': [155],
#    'where': [156, 250],
#    'they': [157],
#    'match': [158],
#    'either': [159],
#    'term': [162],
#    'name': [163],
#    'synonym.': [166],
#    'This': [167],
#    'enables': [168],
#    'rapidly': [172],
#    'further': [176],
#    'based': [178],
#    'possible': [180],
#    'terms.': [182],
#    'Because': [183],
#    'most': [184],
#    'do': [187, 222],
#    'standardized': [190],
#    'literature,': [191],
#    'searches': [193],
#    'names': [196, 209],
#    'synonyms': [198],
#    'associate': [200],
#    'As': [204],
#    'many': [205],
#    'can': [210],
#    'be': [211],
#    'ambiguous,': [212],
#    'applies': [214],
#    'disambiguation': [216],
#    'step': [217],
#    'remove': [219, 233],
#    'matches': [220],
#    'correspond': [224],
#    'this': [226],
#    'gene,': [227],
#    'filtering': [229],
#    'applied': [231],
#    'abstracts': [234],
#    'mention': [236],
#    'in': [239, 301],
#    'passing.': [240],
#    'Journal': [247],
#    'Database': [248, 303],
#    '(JDB)': [249],
#    'corresponding': [251],
#    'journal': [252],
#    'citations': [253, 265],
#    'stored.': [255],
#    'Just': [256],
#    'importantly,': [258],
#    'add': [261],
#    'JDB': [264],
#    'no': [268],
#    'supports': [275],
#    'bulk': [276],
#    'upload': [278],
#    'facilitate': [280],
#    'Inferred': [282],
#    'electronic': [284],
#    'products.': [289],
#    'All': [290],
#    'annotations': [291],
#    'must': [292],
#    'pass': [293],
#    'standard': [294],
#    'Consortium': [296],
#    'quality': [297],
#    'checking': [298],
#    'before': [299],
#    'release': [300],
#    'AgBase.': [302],
#    'URL:': [304],
#    'http://www.agbase.msstate.edu/.': [305]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2097456924',
#   'counts_by_year': [{'year': 2021, 'cited_by_count': 1},
#    {'year': 2020, 'cited_by_count': 1},
#    {'year': 2016, 'cited_by_count': 1},
#    {'year': 2015, 'cited_by_count': 1},
#    {'year': 2014, 'cited_by_count': 2},
#    {'year': 2013, 'cited_by_count': 1}],
#   'updated_date': '2023-01-20T00:13:20.588108',
#   'created_date': '2016-06-24'},
#  {'id': 'https://openalex.org/W2166240318',
#   'doi': 'https://doi.org/10.1093/database/bas056',
#   'title': 'An overview of the BioCreative 2012 Workshop Track III: interactive text mining task',
#   'display_name': 'An overview of the BioCreative 2012 Workshop Track III: interactive text mining task',
#   'relevance_score': 158.26288,
#   'publication_year': 2013,
#   'publication_date': '2013-01-17',
#   'ids': {'openalex': 'https://openalex.org/W2166240318',
#    'doi': 'https://doi.org/10.1093/database/bas056',
#    'mag': '2166240318',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/23327936',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/3625048'},
#   'host_venue': {'id': 'https://openalex.org/V4210201630',
#    'issn_l': '1758-0463',
#    'issn': ['1758-0463'],
#    'display_name': 'Database',
#    'publisher': 'University of Oxford',
#    'type': 'journal',
#    'url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/bas056/16732181/bas056.pdf',
#    'is_oa': True,
#    'version': 'publishedVersion',
#    'license': 'cc-by'},
#   'type': 'journal-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'gold',
#    'oa_url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/bas056/16732181/bas056.pdf'},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A2692381839',
#      'display_name': 'Cecilia N. Arighi',
#      'orcid': 'https://orcid.org/0000-0002-0803-4817'},
#     'institutions': [{'id': 'https://openalex.org/I86501945',
#       'display_name': 'University of Delaware',
#       'ror': 'https://ror.org/01sbq1a82',
#       'country_code': 'US',
#       'type': 'education'}],
#     'raw_affiliation_string': '<italic>University of Delaware</italic>'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2645247999',
#      'display_name': 'Ben Carterette',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I86501945',
#       'display_name': 'University of Delaware',
#       'ror': 'https://ror.org/01sbq1a82',
#       'country_code': 'US',
#       'type': 'education'}],
#     'raw_affiliation_string': '<italic>University of Delaware</italic>'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2162530571',
#      'display_name': 'K. Bretonnel Cohen',
#      'orcid': 'https://orcid.org/0000-0003-1749-8290'},
#     'institutions': [{'id': 'https://openalex.org/I131651094',
#       'display_name': 'University of Denver',
#       'ror': 'https://ror.org/04w7skc03',
#       'country_code': 'US',
#       'type': 'education'}],
#     'raw_affiliation_string': 'University of Colorado Denver'},
#    {'author_position': 'middle',
# ...
#     'author': {'id': 'https://openalex.org/A2065847026',
#      'display_name': 'Sandra Orchard',
#      'orcid': 'https://orcid.org/0000-0002-8878-3972'},
#     'institutions': [{'id': None,
#       'display_name': 'European Molecular Biology Laboratory',
#       'ror': None,
#       'country_code': None,
#       'type': None}],
#     'raw_affiliation_string': 'European Molecular Biology Laboratory'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2080394068',
#      'display_name': 'B. F. Francis Ouellette',
#      'orcid': 'https://orcid.org/0000-0003-4676-675X'},
#     'institutions': [{'id': 'https://openalex.org/I112260969',
#       'display_name': 'Ontario Institute for Cancer Research',
#       'ror': 'https://ror.org/043q8yx54',
#       'country_code': 'CA',
#       'type': 'nonprofit'},
#      {'id': 'https://openalex.org/I2802626578',
#       'display_name': 'Oxford University Press',
#       'ror': 'https://ror.org/0336mm561',
#       'country_code': 'GB',
#       'type': 'company'}],
#     'raw_affiliation_string': 'Ontario Institute for Cancer Research; Oxford University Press'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2116731834',
#      'display_name': 'Shoba Ranganathan',
#      'orcid': 'https://orcid.org/0000-0002-8290-813X'},
#     'institutions': [{'id': 'https://openalex.org/I99043593',
#       'display_name': 'Macquarie University',
#       'ror': 'https://ror.org/01sf06y89',
#       'country_code': 'AU',
#       'type': 'education'},
#      {'id': 'https://openalex.org/I165932596',
#       'display_name': 'National University of Singapore',
#       'ror': 'https://ror.org/01tgyzw49',
#       'country_code': 'SG',
#       'type': 'education'}],
#     'raw_affiliation_string': 'Macquarie University; National University of Singapore'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2097871067',
#      'display_name': 'Lorna Richardson',
#      'orcid': 'https://orcid.org/0000-0002-3655-5660'},
#     'institutions': [{'id': 'https://openalex.org/I1324252669',
#       'display_name': 'NHS Lothian',
#       'ror': 'https://ror.org/03q82t418',
#       'country_code': 'GB',
#       'type': 'healthcare'}],
#     'raw_affiliation_string': ' NHS Lothian'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A396324943',
#      'display_name': 'Philippe Rocca-Serra',
#      'orcid': 'https://orcid.org/0000-0001-9853-5668'},
#     'institutions': [{'id': 'https://openalex.org/I40120149',
#       'display_name': 'University of Oxford',
#       'ror': 'https://ror.org/052gg0110',
#       'country_code': 'GB',
#       'type': 'education'}],
#     'raw_affiliation_string': 'University of Oxford.'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2101704118',
#      'display_name': 'Paul N. Schofield',
#      'orcid': 'https://orcid.org/0000-0002-5111-7263'},
#     'institutions': [{'id': 'https://openalex.org/I241749',
#       'display_name': 'University of Cambridge',
#       'ror': 'https://ror.org/013meh722',
#       'country_code': 'GB',
#       'type': 'education'}],
#     'raw_affiliation_string': 'Univ. of Cambridge'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2247189593',
#      'display_name': 'Damian Smedley',
#      'orcid': 'https://orcid.org/0000-0002-5836-9850'},
#     'institutions': [{'id': None,
#       'display_name': 'European Molecular Biology Laboratory',
#       'ror': None,
#       'country_code': None,
#       'type': None}],
#     'raw_affiliation_string': 'European Molecular Biology Laboratory'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2262399162',
#      'display_name': 'Christopher Southan',
#      'orcid': 'https://orcid.org/0000-0001-9580-0446'},
#     'institutions': [{'id': None,
#       'display_name': 'ChrisDS Consulting',
#       'ror': None,
#       'country_code': None,
#       'type': None}],
#     'raw_affiliation_string': 'ChrisDS Consulting'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2170850377',
#      'display_name': 'Tin Wee Tan',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I165932596',
#       'display_name': 'National University of Singapore',
#       'ror': 'https://ror.org/01tgyzw49',
#       'country_code': 'SG',
#       'type': 'education'}],
#     'raw_affiliation_string': 'National University of Singapore,'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2053101140',
#      'display_name': 'Tatiana Tatusova',
#      'orcid': None},
#     'institutions': [{'id': None,
#       'display_name': ' National Institutes of Health',
#       'ror': None,
#       'country_code': None,
#       'type': None}],
#     'raw_affiliation_string': ' National Institutes of Health'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A1517510072',
#      'display_name': 'Patricia L. Whetzel',
#      'orcid': 'https://orcid.org/0000-0002-3458-4839'},
#     'institutions': [{'id': 'https://openalex.org/I97018004',
#       'display_name': 'Stanford University',
#       'ror': 'https://ror.org/00f54p054',
#       'country_code': 'US',
#       'type': 'education'}],
#     'raw_affiliation_string': 'Stanford University ()'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2160736014',
#      'display_name': 'Owen White',
#      'orcid': 'https://orcid.org/0000-0002-2836-7344'},
#     'institutions': [{'id': 'https://openalex.org/I126744593',
#       'display_name': 'University of Maryland, Baltimore',
#       'ror': 'https://ror.org/04rq5mt64',
#       'country_code': 'US',
#       'type': 'education'}],
#     'raw_affiliation_string': 'University of Maryland-Baltimore'},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A1982445405',
#      'display_name': 'Chisato Yamasaki',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I73613424',
#       'display_name': 'National Institute of Advanced Industrial Science and Technology',
#       'ror': 'https://ror.org/01703db54',
#       'country_code': 'JP',
#       'type': 'government'}],
#     'raw_affiliation_string': 'National Institute of Advanced Industrial Science and#N#                  Technology'}],
#   'cited_by_count': 33,
#   'biblio': {'volume': '39',
#    'issue': 'suppl_1',
#    'first_page': 'D7',
#    'last_page': 'D10'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C20136886',
#     'wikidata': 'https://www.wikidata.org/wiki/Q749647',
#     'display_name': 'Interoperability',
#     'level': 2,
#     'score': '0.6876779'},
#    {'id': 'https://openalex.org/C2778012447',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1034415',
#     'display_name': 'Scope (computer science)',
#     'level': 2,
#     'score': '0.6868291'},
#    {'id': 'https://openalex.org/C158154518',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7310970',
#     'display_name': 'Relevance (law)',
#     'level': 2,
#     'score': '0.6596437'},
#    {'id': 'https://openalex.org/C2776436953',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5163215',
#     'display_name': 'Consistency (knowledge bases)',
#     'level': 2,
#     'score': '0.6086125'},
#    {'id': 'https://openalex.org/C77088390',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8513',
#     'display_name': 'Database',
#     'level': 1,
#     'score': '0.5538324'},
#    {'id': 'https://openalex.org/C206345919',
#     'wikidata': 'https://www.wikidata.org/wiki/Q20380951',
#     'display_name': 'Resource (disambiguation)',
#     'level': 2,
#     'score': '0.51033944'},
#    {'id': 'https://openalex.org/C2778180026',
#     'wikidata': 'https://www.wikidata.org/wiki/Q18378163',
#     'display_name': 'Semantic heterogeneity',
#     'level': 4,
#     'score': '0.45727634'},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': '0.4335835'},
#    {'id': 'https://openalex.org/C20901353',
#     'wikidata': 'https://www.wikidata.org/wiki/Q4117139',
#     'display_name': 'Biological database',
#     'level': 2,
#     'score': '0.4184407'},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': '0.3763256'},
#    {'id': 'https://openalex.org/C56739046',
#     'wikidata': 'https://www.wikidata.org/wiki/Q192060',
#     'display_name': 'Knowledge management',
#     'level': 1,
#     'score': '0.37409532'},
#    {'id': 'https://openalex.org/C2522767166',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2374463',
#     'display_name': 'Data science',
#     'level': 1,
#     'score': '0.3658772'},
#    {'id': 'https://openalex.org/C23123220',
#     'wikidata': 'https://www.wikidata.org/wiki/Q816826',
#     'display_name': 'Information retrieval',
#     'level': 1,
#     'score': '0.30729812'},
#    {'id': 'https://openalex.org/C136764020',
#     'wikidata': 'https://www.wikidata.org/wiki/Q466',
#     'display_name': 'World Wide Web',
#     'level': 1,
#     'score': '0.27206987'},
#    {'id': 'https://openalex.org/C2129575',
#     'wikidata': 'https://www.wikidata.org/wiki/Q54837',
#     'display_name': 'Semantic Web',
#     'level': 2,
#     'score': '0.2181764'},
#    {'id': 'https://openalex.org/C60644358',
#     'wikidata': 'https://www.wikidata.org/wiki/Q128570',
#     'display_name': 'Bioinformatics',
#     'level': 1,
#     'score': '0.12011549'},
#    {'id': 'https://openalex.org/C31258907',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1301371',
#     'display_name': 'Computer network',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C22550185',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7095047',
#     'display_name': 'Ontology-based data integration',
#     'level': 3,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C199539241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#     'display_name': 'Law',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C199360897',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#     'display_name': 'Programming language',
#     'level': 1,
#     'score': '0.0'}],
#   'mesh': [{'descriptor_ui': 'D016208',
#     'descriptor_name': 'Databases, Factual',
#     'qualifier_ui': 'Q000592',
#     'qualifier_name': 'standards',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D016208',
#     'descriptor_name': 'Databases, Factual',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D033181',
#     'descriptor_name': 'Information Dissemination',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False}],
#   'alternate_host_venues': [{'id': 'https://openalex.org/V134668137',
#     'display_name': 'Nucleic Acids Research',
#     'type': 'journal',
#     'url': 'https://academic.oup.com/nar/article-pdf/39/suppl_1/D7/18786889/gkq1173.pdf',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by-nc'},
#    {'id': 'https://openalex.org/V4306400806',
#     'display_name': 'PubMed Central - Europe PMC',
#     'type': 'repository',
#     'url': 'https://europepmc.org/articles/pmc3013734?pdf=render',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by-nc'},
#    {'id': 'https://openalex.org/V4306400148',
#     'display_name': 'reroDoc Digital Library',
#     'type': 'repository',
#     'url': 'http://doc.rero.ch/record/299459/files/gkq1173.pdf',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by-nc'},
#    {'id': 'https://openalex.org/V4306402259',
#     'display_name': 'University of Geneva - Archive ouverte UNIGE',
#     'type': 'repository',
#     'url': 'https://archive-ouverte.unige.ch/unige:36257/ATTACHMENT01',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by-nc'},
#    {'id': 'https://openalex.org/V4306400655',
#     'display_name': 'Max Planck Society - MPG.PuRe',
#     'type': 'repository',
#     'url': 'https://pure.mpg.de/pubman/item/item_1552221_3/component/file_2078023/Gaudet_Towards_NAR_2010.pdf',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by-nc'},
#    {'id': 'https://openalex.org/V2764455111',
#     'display_name': 'PubMed Central',
#     'type': 'repository',
#     'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3013734',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': None},
#    {'id': None,
#     'display_name': None,
#     'type': 'repository',
#     'url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/baq027/1251734/baq027.pdf',
#     'is_oa': True,
#     'version': 'submittedVersion',
#     'license': 'cc-by-nc'},
#    {'id': 'https://openalex.org/V4306402487',
#     'display_name': 'U.S. Department of Energy Office of Scientific and Technical Information - OSTI OAI',
#     'type': 'repository',
#     'url': 'https://www.osti.gov/biblio/1625473',
#     'is_oa': True,
#     'version': 'submittedVersion',
#     'license': None}],
#   'referenced_works': ['https://openalex.org/W1618455174',
#    'https://openalex.org/W1971676632',
#    'https://openalex.org/W2050554833',
#    'https://openalex.org/W2084115201',
#    'https://openalex.org/W2091940856',
#    'https://openalex.org/W2092563396',
#    'https://openalex.org/W2100599058',
#    'https://openalex.org/W2113439138',
#    'https://openalex.org/W2113701936',
#    'https://openalex.org/W2131152203',
#    'https://openalex.org/W2141132558'],
#   'related_works': ['https://openalex.org/W275392788',
#    'https://openalex.org/W1584628001',
#    'https://openalex.org/W1706114401',
#    'https://openalex.org/W2036641180',
#    'https://openalex.org/W2076349684',
#    'https://openalex.org/W2082765800',
#    'https://openalex.org/W2619078905',
#    'https://openalex.org/W2781814656',
#    'https://openalex.org/W2921507169',
#    'https://openalex.org/W2943822580'],
#   'ngrams_url': 'https://api.openalex.org/works/W2121237412/ngrams',
#   'abstract_inverted_index': {'The': [0, 20],
#    'present': [1, 79],
#    'article': [2],
#    'proposes': [3],
#    'the': [4, 13, 32, 45, 61, 73, 77],
#    'adoption': [5],
#    'of': [6, 12, 16, 22, 31, 47, 65, 76],
#    'a': [7, 28],
#    'community-defined,': [8],
#    'uniform,': [9],
#    'generic': [10],
#    'description': [11],
#    'core': [14],
#    'attributes': [15, 24],
#    'biological': [17, 81],
#    'databases,': [18],
#    'BioDBCore.': [19],
#    'goals': [21],
#    'these': [23],
#    'are': [25],
#    'to': [26, 35, 43, 59],
#    'provide': [27],
#    'general': [29],
#    'overview': [30],
#    'database': [33],
#    'landscape,': [34],
#    'encourage': [36],
#    'consistency': [37],
#    'and': [38, 42, 49, 63],
#    'interoperability': [39],
#    'between': [40],
#    'resources': [41],
#    'promote': [44],
#    'use': [46],
#    'semantic': [48],
#    'syntactic': [50],
#    'standards.': [51],
#    'BioDBCore': [52],
#    'will': [53, 71],
#    'make': [54],
#    'it': [55],
#    'easier': [56],
#    'for': [57],
#    'users': [58],
#    'evaluate': [60],
#    'scope': [62],
#    'relevance': [64],
#    'available': [66],
#    'resources.': [67],
#    'This': [68],
#    'new': [69],
#    'resource': [70],
#    'increase': [72],
#    'collective': [74],
#    'impact': [75],
#    'information': [78],
#    'in': [80],
#    'databases.': [82]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2121237412',
#   'counts_by_year': [{'year': 2020, 'cited_by_count': 1},
#    {'year': 2019, 'cited_by_count': 1},
#    {'year': 2018, 'cited_by_count': 1},
#    {'year': 2017, 'cited_by_count': 1},
#    {'year': 2016, 'cited_by_count': 1},
#    {'year': 2015, 'cited_by_count': 1},
#    {'year': 2014, 'cited_by_count': 2},
#    {'year': 2013, 'cited_by_count': 7},
#    {'year': 2012, 'cited_by_count': 10}],
#   'updated_date': '2023-01-29T18:56:15.429505',
#   'created_date': '2016-06-24'}]
